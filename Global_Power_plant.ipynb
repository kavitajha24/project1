# %%
#importing nesscessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
url='https://raw.githubusercontent.com/wri/global-power-plant-database/master/source_databases_csv/database_IND.csv'

# %%
data=pd.read_csv(url)
data
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 903     IND        India                  YERMARUS TPP  IND0000513
# 904     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 905     IND        India  Yelisirur wind power project  WRI1026776
# 906     IND        India                   ZAWAR MINES  WRI1019901
# 907     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
#shape of tha data=
data.shape
# Out:
# (908, 25)

# %% [markdown]
# there are
#
# 908- rows
#
# 25- columns

# %%
#al the column names that are present in dataset
data.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
#some information about datset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   908 non-null    object
#  1   country_long              908 non-null    object
#  2   name                      908 non-null    object
#  3   gppd_idnr                 908 non-null    object
#  4   capacity_mw               908 non-null    float64
#  5   latitude                  862 non-null    float64
#  6   longitude                 862 non-null    float64
#  7   primary_fuel              908 non-null    object
#  8   other_fuel1               199 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        528 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %% [markdown]
# it gives us datatypes or null values that are present in the dataset and we see there are lot of null values present in maximum number of columns

# %%
#lets check one by one null values in each column
data.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 907
# other_fuel3                 908
# commissioning_year          380
# owner                       566
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     908
# year_of_capacity_data       388
# generation_gwh_2013         524
# generation_gwh_2014         507
# generation_gwh_2015         483
# generation_gwh_2016         471
# generation_gwh_2017         465
# generation_data_source      458
# estimated_generation_gwh    908
# dtype: int64

# %%
#datatypes of each column i.e what type of data column held in 
data.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_data_source       object
# estimated_generation_gwh    float64
# dtype: object

# %%
#lets summarize the dataset
data.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   908.000000  862.000000  862.000000          0.0          528.000000
# mean    321.046378   21.196189   77.447848          NaN         1996.876894
# std     580.221767    6.248627    4.907260          NaN           17.047817
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.837500   16.771575   74.258975          NaN         1988.000000
# 50%      60.000000   21.778300   76.719250          NaN         2000.000000
# 75%     388.125000   25.516375   79.441475          NaN         2011.250000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  520.0           384.000000
# mean       NaN                 2018.0          2304.059202
# std        NaN                    0.0          3794.767492
# ...

# %% [markdown]
# mean,std 1st quantile ,2 nd quantile and 3rd quentile of each column computed individually

# %% [markdown]
# #### unique values of each columns
# lets check the unique values of all columns to see weather its useful or not oe wether we can convert it into numeric or not

# %%
# country column
data['country'].unique()
# Out:
# array(['IND'], dtype=object)

# %% [markdown]
# there are only one unique values in this column which is India so if there is only one value or it is in object form so we can drop this column according to our need

# %%
##drop this country column
data=data.drop(columns=['country'])
data
# Out:
#     country_long                          name   gppd_idnr  capacity_mw  \
# 0          India              ACME Solar Tower  WRI1020239          2.5
# 1          India           ADITYA CEMENT WORKS  WRI1019881         98.0
# 2          India      AES Saurashtra Windfarms  WRI1026669         39.2
# 3          India                   AGARTALA GT  IND0000001        135.0
# 4          India                  AKALTARA TPP  IND0000002       1800.0
# ..           ...                           ...         ...          ...
# 903        India                  YERMARUS TPP  IND0000513       1600.0
# 904        India  Yelesandra Solar Power Plant  WRI1026222          3.0
# 905        India  Yelisirur wind power project  WRI1026776         25.5
# 906        India                   ZAWAR MINES  WRI1019901         80.0
# 907        India       iEnergy Theni Wind Farm  WRI1026761         16.5
#
#      latitude  longitude primary_fuel other_fuel1 other_fuel2  other_fuel3  \
# ...

# %% [markdown]
# we have deleted this country column beacuse it has only one value and we don't need ay specific column for this

# %%
#unique value of country_long
data['country_long'].unique()
# Out:
# array(['India'], dtype=object)

# %% [markdown]
# there is also only one value in country_long column we can even drop this

# %%
#dropping country_long 
data=data.drop(columns=['country_long'])
data
# Out:
#                              name   gppd_idnr  capacity_mw  latitude  \
# 0                ACME Solar Tower  WRI1020239          2.5   28.1839
# 1             ADITYA CEMENT WORKS  WRI1019881         98.0   24.7663
# 2        AES Saurashtra Windfarms  WRI1026669         39.2   21.9038
# 3                     AGARTALA GT  IND0000001        135.0   23.8712
# 4                    AKALTARA TPP  IND0000002       1800.0   21.9603
# ..                            ...         ...          ...       ...
# 903                  YERMARUS TPP  IND0000513       1600.0   16.2949
# 904  Yelesandra Solar Power Plant  WRI1026222          3.0   12.8932
# 905  Yelisirur wind power project  WRI1026776         25.5   15.2758
# 906                   ZAWAR MINES  WRI1019901         80.0   24.3500
# 907       iEnergy Theni Wind Farm  WRI1026761         16.5    9.9344
#
#      longitude primary_fuel other_fuel1 other_fuel2  other_fuel3  \
# 0      73.2407        Solar         NaN         NaN          NaN
# ...

# %% [markdown]
# we have deleted this column because it also has only one value 'india'

# %%
#check unique values of name column
data['name'].unique()
# Out:
# array(['ACME Solar Tower', 'ADITYA CEMENT WORKS',
#        'AES Saurashtra Windfarms', 'AGARTALA GT', 'AKALTARA TPP',
#        'AKRIMOTA LIG', 'ALIYAR', 'ALLAIN DUHANGAN', 'ALMATTI DAM',
#        'AMAR KANTAK', 'AMARAVATI TPP', 'ANANDPUR SAHIB ST-I&II',
#        'ANAPARA "C"', 'ANDHRA', 'ANOOPGARH ST I&II', 'ANPARA', 'ANTA GT',
#        'ANUPPUR', 'ANUPUR TPP', 'ARVINDNAGAR SUGAR', 'ASHOKNAGAR MILL',
#        'ATHANI SUGAR', 'AURAIYA GT', 'AVANTHA BHANDAR TPP',
#        'AWARPUR CEMENT PLANT', 'Abhijeet', 'Amarsar Solar Power Plant',
#        'Anabura Wind Farm', 'Ananthapur - Meil Solar Power Plant',
#        'Andrha Lake Wind Farm', 'Anikkadavu Wind Farm',
#        'Arasinagundi Wind Farm', 'Askandra - DREPL Solar Power Plant',
#        'Askandra - Electromech Maritech Solar Power Plant',
#        'Askandra - Finehope Solar Power Plant',
#        'Askandra - Khaya Solar Power Plant',
#        'Askandra - Newton Solar Power Plant',
#        'Askandra - Saidham Solar Power Plant',
# ...

# %% [markdown]
# there are so many unique values in this column which is only the name of the power plant we can also delete this instead of converting it

# %%
#dropping name column
data=data.drop(columns=['name'])
data
# Out:
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0    WRI1020239          2.5   28.1839    73.2407        Solar         NaN
# 1    WRI1019881         98.0   24.7663    74.6090         Coal         NaN
# 2    WRI1026669         39.2   21.9038    69.3732         Wind         NaN
# 3    IND0000001        135.0   23.8712    91.3602          Gas         NaN
# 4    IND0000002       1800.0   21.9603    82.4091         Coal         Oil
# ..          ...          ...       ...        ...          ...         ...
# 903  IND0000513       1600.0   16.2949    77.3568         Coal         Oil
# 904  WRI1026222          3.0   12.8932    78.1654        Solar         NaN
# 905  WRI1026776         25.5   15.2758    75.5811         Wind         NaN
# 906  WRI1019901         80.0   24.3500    73.7477         Coal         NaN
# 907  WRI1026761         16.5    9.9344    77.4768         Wind         NaN
#
#     other_fuel2  other_fuel3  commissioning_year  \
# ...

# %% [markdown]
# we have deleted this column

# %%
#checking unique values of gppd_idnr column
data['gppd_idnr'].unique()
# Out:
# array(['WRI1020239', 'WRI1019881', 'WRI1026669', 'IND0000001',
#        'IND0000002', 'IND0000003', 'IND0000004', 'IND0000005',
#        'IND0000006', 'IND0000007', 'IND0000008', 'IND0000009',
#        'IND0000010', 'IND0000011', 'IND0000012', 'IND0000013',
#        'IND0000014', 'WRI1019996', 'IND0000015', 'WRI1019938',
#        'WRI1019939', 'WRI1019904', 'IND0000016', 'IND0000017',
#        'WRI1019940', 'WRI1020238', 'WRI1026104', 'WRI1026069',
#        'WRI1026105', 'WRI1026768', 'WRI1026347', 'WRI1026068',
#        'WRI1026106', 'WRI1026107', 'WRI1026108', 'WRI1026109',
#        'WRI1026110', 'WRI1026111', 'WRI1026112', 'IND0000018',
#        'IND0000019', 'WRI1019905', 'IND0000020', 'IND0000021',
#        'IND0000022', 'IND0000023', 'IND0000025', 'IND0000024',
#        'WRI1019941', 'WRI1019882', 'IND0000026', 'IND0000027',
#        'IND0000028', 'IND0000029', 'IND0000030', 'IND0000031',
#        'IND0000032', 'WRI1019883', 'IND0000033', 'IND0000034',
# ...

# %% [markdown]
# even this column have unique values in so many of numbers ans itd just the id of power plant name which is not useful for prediction we can drop this

# %%
#dropping gppd_idnr
data=data.drop(columns=['gppd_idnr'])
data
# Out:
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# 1           98.0   24.7663    74.6090         Coal         NaN         NaN
# 2           39.2   21.9038    69.3732         Wind         NaN         NaN
# 3          135.0   23.8712    91.3602          Gas         NaN         NaN
# 4         1800.0   21.9603    82.4091         Coal         Oil         NaN
# ..           ...       ...        ...          ...         ...         ...
# 903       1600.0   16.2949    77.3568         Coal         Oil         NaN
# 904          3.0   12.8932    78.1654        Solar         NaN         NaN
# 905         25.5   15.2758    75.5811         Wind         NaN         NaN
# 906         80.0   24.3500    73.7477         Coal         NaN         NaN
# 907         16.5    9.9344    77.4768         Wind         NaN         NaN
#
# ...

# %%
#checking primary column unique values
data['primary_fuel'].unique()
# Out:
# array(['Solar', 'Coal', 'Wind', 'Gas', 'Hydro', 'Biomass', 'Oil',
#        'Nuclear'], dtype=object)

# %% [markdown]
# these are the unique values that primary_fuel column has now lets check for value count of this column

# %%
#checking value_count of primary_fuel
data['primary_fuel'].value_counts()
# Out:
# Coal       259
# Hydro      250
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         21
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
# all these are the value count that each unique value have in this column

# %%
#lets plot value count
sns.countplot(data['primary_fuel'])
plt.show()

# %% [markdown]
# as we see in graph highest is coal and lowest is nuclear

# %%
#lets encode primary column 
from sklearn.preprocessing import LabelEncoder

# %%
l1=LabelEncoder()  #instantiate
df1=l1.fit_transform(data['primary_fuel'])
data['primary_fuel']=df1
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407             6         NaN         NaN
# 1           98.0   24.7663    74.6090             1         NaN         NaN
# 2           39.2   21.9038    69.3732             7         NaN         NaN
# 3          135.0   23.8712    91.3602             2         NaN         NaN
# 4         1800.0   21.9603    82.4091             1         Oil         NaN
# ..           ...       ...        ...           ...         ...         ...
# 903       1600.0   16.2949    77.3568             1         Oil         NaN
# 904          3.0   12.8932    78.1654             6         NaN         NaN
# 905         25.5   15.2758    75.5811             7         NaN         NaN
# 906         80.0   24.3500    73.7477             1         NaN         NaN
# 907         16.5    9.9344    77.4768             7         NaN         NaN
#
# ...

# %% [markdown]
# we have converted the primary_fuel column into numbers

# %%
# again checking value_count of primary_fuel
data['primary_fuel'].value_counts()
# Out:
# 1    259
# 3    250
# 6    127
# 7    123
# 2     69
# 0     50
# 5     21
# 4      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
# Coal       1
# Hydro      2
# Solar      3
# Wind       4
# Gas        5
# Biomass    6
# Oil        7
# Nuclear    8
#
# we have concerted the values of promary fuel into numbers

# %%
#checking uniquevalues of other_fuel1 column
data['other_fuel1'].unique()
# Out:
# array([nan, 'Oil', 'Cogeneration', 'Gas'], dtype=object)

# %% [markdown]
# these are the unique values that are availabel in other_fuel1 column
#
# we can check now the value counts of this column

# %%
#checkimg value counts of other_fuel1
data['other_fuel1'].value_counts()
# Out:
# Oil             196
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64

# %%
#lets plot for unique values in other_fuel column
sns.countplot(data['other_fuel1'])
plt.show()

# %% [markdown]
# the count of oil oil is high but the count nan values is much bigger so we can't cahnge it to high else we impute it to 0 or change it to zero

# %%
data['other_fuel1'].isna().sum()
# Out:
# 709

# %%
#lets treat nan values of other_fuel1
data['other_fuel1']=data['other_fuel1'].fillna('A')  #we have assign A to all the null values beacuse it will become 0 while label encoding that will be easier us to understand that 0 means null values

# %% [markdown]
# we have assign A to all the null values beacuse it will become 0 while label encoding that will be easier us to understand that 0 means null values

# %%
#gain check the count values of other_fuel1 colmumn
data['other_fuel1'].value_counts()
# Out:
# A               709
# Oil             196
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64

# %%
#again check the unique values of other_fuel1 column
data['other_fuel1'].unique()
# Out:
# array(['A', 'Oil', 'Cogeneration', 'Gas'], dtype=object)

# %%
#plot the count plot for the values of other_fuel1
sns.countplot(data['other_fuel1'])
# Out:
# <AxesSubplot:xlabel='other_fuel1', ylabel='count'>

# %% [markdown]
# as we can see in the graph that the max number of values are 0 then oil and then gas and last cogeneration

# %%
#lets encode other_fuel1 other inputs
l2=LabelEncoder()  #again instantiating 
df2=l2.fit_transform(data['other_fuel1'])
data['other_fuel1']=df2
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407             6            0         NaN
# 1           98.0   24.7663    74.6090             1            0         NaN
# 2           39.2   21.9038    69.3732             7            0         NaN
# 3          135.0   23.8712    91.3602             2            0         NaN
# 4         1800.0   21.9603    82.4091             1            3         NaN
# ..           ...       ...        ...           ...          ...         ...
# 903       1600.0   16.2949    77.3568             1            3         NaN
# 904          3.0   12.8932    78.1654             6            0         NaN
# 905         25.5   15.2758    75.5811             7            0         NaN
# 906         80.0   24.3500    73.7477             1            0         NaN
# 907         16.5    9.9344    77.4768             7            0         NaN
#
# ...

# %% [markdown]
# in other_fuel1 column
#
# A- 0 )nan values that we have converted to A is now converted to zero
#
# congeration-1
#
# gas--2
#
# oil--3

# %%
#again plot countplot to recheck
sns.countplot(data['other_fuel1'])
plt.show()

# %%
#now check the datatype of other_fuel1
data['other_fuel1'].dtypes
# Out:
# dtype('int32')

# %% [markdown]
# we have converted the datatype of other_fuel1 column

# %%
#other_fuel2 column unique values
data['other_fuel2'].unique()
# Out:
# array([nan, 'Oil'], dtype=object)

# %% [markdown]
# there are only two unique values nan or oil

# %%
#lets check the values count of other_fuel2 column
data['other_fuel2'].value_counts()
# Out:
# Oil    1
# Name: other_fuel2, dtype: int64

# %%
#lets check the null valyes of other_fuel2
data['other_fuel2'].isna().sum()
# Out:
# 907

# %% [markdown]
# through all the values of other_value2 column only one is filled with oil else all are nan values so we could not assume all the values in one particular column so better to drop it

# %%
#dropping other_fuel2 column

data=data.drop(columns=['other_fuel2'])
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  other_fuel3  \
# 0            2.5   28.1839    73.2407             6            0          NaN
# 1           98.0   24.7663    74.6090             1            0          NaN
# 2           39.2   21.9038    69.3732             7            0          NaN
# 3          135.0   23.8712    91.3602             2            0          NaN
# 4         1800.0   21.9603    82.4091             1            3          NaN
# ..           ...       ...        ...           ...          ...          ...
# 903       1600.0   16.2949    77.3568             1            3          NaN
# 904          3.0   12.8932    78.1654             6            0          NaN
# 905         25.5   15.2758    75.5811             7            0          NaN
# 906         80.0   24.3500    73.7477             1            0          NaN
# 907         16.5    9.9344    77.4768             7            0          NaN
#
# ...

# %% [markdown]
# we have deleted the other_fuel2 column from dataset

# %%
#noe lets the unique value of other_fuel3 column

data['other_fuel3'].unique()
# Out:
# array([nan])

# %% [markdown]
# in this column are the values are null values so we couldn;t assume all the values in it so better to drop it

# %%
#dropping other_fuel3 column from dataset

data=data.drop(columns=['other_fuel3'])
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#      commissioning_year                                owner  \
# 0                2011.0                          Solar Paces
# ...

# %% [markdown]
# we have sucessfully dropped other_fuel3 column from dataet

# %%
#lets check unique values of commissionning_yesr column 
data['commissioning_year'].unique()
# Out:
# array([2011.,   nan, 2004., 2015., 2005., 1970., 2010., 2008., 2014.,
#        1985., 1986., 1987., 2000., 1989., 2017., 1998., 1977., 1980.,
#        2003., 1984., 1973., 1996., 1991., 2002., 2001., 2006., 2007.,
#        1988., 2012., 1968., 1964., 2016., 2013., 1962., 1993., 1997.,
#        1999., 1994., 1975., 1992., 1972., 1979., 1967., 1995., 1983.,
#        1981., 1959., 1961., 1957., 1978., 1976., 1963., 1971., 1955.,
#        2018., 2009., 1966., 1965., 1960., 1949., 1952., 1990., 1982.,
#        1937., 1956., 1946., 1958., 1943., 1954., 1969., 1939., 1927.,
#        1974., 1953.])

# %%
#lets check the null values that the column has
data['commissioning_year'].isna().sum()
# Out:
# 380

# %% [markdown]
# we should drop this column as if only has year of starting infomation which is of no use to predict any of the column

# %%
#dropping commissioning column from dataset
data=data.drop(columns=['commissioning_year'])
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#                                    owner  \
# 0                            Solar Paces
# 1                   Ultratech Cement ltd
# 2                                    AES
# ...

# %% [markdown]
# now nest three column are owenr , souces and url which we can;t convert can;t normalise and can;t predict so better to drop them

# %%
#drooping owner, sources and url columns from adtaset
data=data.drop(columns=['owner','source','url'])
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#                        geolocation_source  wepp_id  year_of_capacity_data  \
# 0    National Renewable Energy Laboratory      NaN                    NaN
# ...

# %%
#lets check unique values of geolocation source column
data['geolocation_source'].unique()
# Out:
# array(['National Renewable Energy Laboratory', 'WRI', nan,
#        'Industry About'], dtype=object)

# %%
#lets check the count of null values in geolocation souce column
data['geolocation_source'].isna().sum()
# Out:
# 19

# %%
#lets check thecount number of each column in geolocatoion column
data['geolocation_source'].value_counts()
# Out:
# WRI                                     766
# Industry About                          119
# National Renewable Energy Laboratory      4
# Name: geolocation_source, dtype: int64

# %%
#lets plot countnumbers 
sns.countplot(data['geolocation_source'])
plt.show()

# %% [markdown]
# as we see the highest are WRI so we change are nan values to WRI because there are high chances that they belong to them

# %%
#we are changing the null values to WRI
data['geolocation_source']=data['geolocation_source'].fillna('WRI')
data['geolocation_source']
# Out:
# 0      National Renewable Energy Laboratory
# 1                                       WRI
# 2                                       WRI
# 3                                       WRI
# 4                                       WRI
#                        ...
# 903                                     WRI
# 904                          Industry About
# 905                                     WRI
# 906                                     WRI
# 907                                     WRI
# Name: geolocation_source, Length: 908, dtype: object

# %% [markdown]
# we have changed the null values of geolocation_source column to WRI

# %%
#check the null avlues of geolocation_source column
data['geolocation_source'].isna().sum()
# Out:
# 0

# %% [markdown]
# now there are no null values in geolocation_source column

# %%
#lets check the unique values of weep_id column
data['wepp_id'].unique()
# Out:
# array([nan])

# %% [markdown]
# in this column all the values are null values we can't assume anything for this column we simply drop this column

# %%
#dropping wepp_id column
data=data.drop(columns=['wepp_id'])
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#                        geolocation_source  year_of_capacity_data  \
# 0    National Renewable Energy Laboratory                    NaN
# ...

# %%
#lets check the unique values of generation_gwh_2013 column
data['generation_gwh_2013'].unique()
# Out:
# array([           nan, 6.31777928e+02, 1.66829000e+03, 8.21798000e+02,
#        1.47568450e+02, 6.96738800e+02, 5.04813250e+02, 2.64232200e+03,
#        1.03405000e+03, 7.31334950e+02, 6.39700000e+03, 7.13299500e+03,
#        1.91994200e+03, 1.73000000e+03, 0.00000000e+00, 8.04286000e+02,
#        3.76900000e+03, 2.78580100e+03, 6.34849800e+02, 6.27422600e+03,
#        1.64754090e+03, 1.18871000e+03, 1.65046620e+03, 1.47080900e+02,
#        1.23778000e+02, 2.27570000e+00, 2.57835110e+02, 5.44672950e+02,
#        4.87135000e+00, 4.48100000e+02, 1.25663600e+03, 8.21705000e-01,
#        1.33876255e+03, 2.27506750e+02, 5.65200000e+03, 6.34710500e+01,
#        6.17923855e+03, 9.03460000e+01, 8.56894000e+01, 2.49148000e+01,
#        4.10935000e+01, 3.31861000e+03, 9.64612700e+02, 9.48732500e+01,
#        3.03007350e+02, 4.36099800e+03, 1.42839040e+03, 1.52042000e+03,
#        2.79729000e+01, 3.36680000e+02, 5.49337000e+03, 2.20064150e+02,
# ...

# %%
#lets check the null values in generation_gwh_2013 column
data['generation_gwh_2013'].isna().sum()
# Out:
# 524

# %% [markdown]
# there are 524 null values generation_gwh_2013 column we can fillit with mean method

# %%
#now encode the string typr to int type with label encoder
l3=LabelEncoder()  #again instantiating
df3=l3.fit_transform(data['geolocation_source'])
data['geolocation_source']=df3
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#      geolocation_source  year_of_capacity_data  generation_gwh_2013  \
# 0                     1                    NaN                  NaN
# ...

# %% [markdown]
# we ahve converted the ttring type to int type
#
# WRI                                     766
# Industry About                          119
# National Renewable Energy Laboratory      4

# %%
#lets check the count value of geolocatiom source
data['geolocation_source'].value_counts()
# Out:
# 2    785
# 0    119
# 1      4
# Name: geolocation_source, dtype: int64

# %% [markdown]
# WRI                                                               2
#
# Industry About                                                    0
#
# National Renewable Energy Laboratory                              1
#
# these are new values of geolocation souce column

# %%
#lets plot countplot for geolocatoon_source column
sns.countplot(data['geolocation_source'])
plt.show()

# %% [markdown]
# WRI is highest
#
#  industry about is in 2nd
#
#  national renewable is in 3rd

# %%
#we treat null values of generation_gwh_2013
data['generation_gwh_2013']=data['generation_gwh_2013'].fillna(data['generation_gwh_2013'].mean())
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#      geolocation_source  year_of_capacity_data  generation_gwh_2013  \
# 0                     1                    NaN          2304.059202
# ...

# %%
#again check the null values of generation_gwh_2013
data['generation_gwh_2013'].isna().sum()
# Out:
# 0

# %% [markdown]
# we have changed the null values to the mean of the column

# %%
#check the unique values of year_of_capacity_data column
data['year_of_capacity_data'].unique()
# Out:
# array([  nan, 2018.])

# %% [markdown]
# there are only 2018 and null values inthe column lets check the value counts

# %%
#check the null values counts of year_of_capacity_data column
data['year_of_capacity_data'].isna().sum()
# Out:
# 388

# %% [markdown]
# there are 388 null values now lets check the count of 2018 in year_of_capacity_data

# %%
#check the count values of year_of_capacity_data column
data['year_of_capacity_data'].value_counts()
# Out:
# 2018.0    520
# Name: year_of_capacity_data, dtype: int64

# %% [markdown]
# as there are only one values and thre are null values of other we could'nt assume all are 2018 we better we dropprd it

# %%
#dropping year_of_capacity_data olumn
data=data.drop(columns=['year_of_capacity_data'])
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#      geolocation_source  generation_gwh_2013  generation_gwh_2014  \
# 0                     1          2304.059202                  NaN
# ...

# %% [markdown]
# we have dropped the year_of_capacity_data columnsa as there are no other values

# %%
#lets the unique values of generation_gwh_2014 column
data['generation_gwh_2014'].unique()
# Out:
# array([           nan, 6.17789264e+02, 3.03555000e+03, 1.15342100e+03,
#        1.57558250e+02, 6.74391100e+02, 4.80594950e+02, 1.88790400e+03,
#        1.92097100e+03, 6.14412500e+02, 7.74400000e+03, 9.67087900e+03,
#        1.61198700e+03, 1.60700000e+03, 0.00000000e+00, 5.73274000e+02,
#        2.93600000e+03, 2.92521045e+03, 7.92686650e+02, 7.23528100e+03,
#        1.33253385e+03, 9.46141000e+02, 1.07595320e+03, 8.56595500e+01,
#        1.20444750e+02, 2.65780000e+02, 3.04832800e+02, 4.95967700e+02,
#        1.22100000e+03, 5.05760000e+02, 1.25573200e+03, 2.85387000e+00,
#        1.24631710e+03, 2.93534950e+02, 5.44576300e+03, 5.03370500e+01,
#        5.24180925e+03, 6.50730000e+01, 1.36872200e+02, 6.75605000e+01,
#        2.96272000e+03, 8.32884650e+02, 9.07937500e+01, 2.99176600e+02,
#        5.85507000e+03, 2.23699080e+03, 1.43887000e+03, 8.11580000e+00,
#        1.45560000e+02, 5.37195000e+03, 2.34650850e+02, 3.30595670e+03,
# ...

# %% [markdown]
# there are lota of unique values generation_gwh_2014 column and as we can see there are null values also so first check the count of null values

# %%
#checking the null values of generation_gwh_2014 column
data['generation_gwh_2014'].isna().sum()
# Out:
# 507

# %% [markdown]
# there are 507 null values sre present i  generation_gwh_2014 column we concert it to mean of the column

# %%
#converting null vaues to the mean of generation_gwh_2014 column
data['generation_gwh_2014']=data['generation_gwh_2014'].fillna(data['generation_gwh_2014'].mean())
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#      geolocation_source  generation_gwh_2013  generation_gwh_2014  \
# 0                     1          2304.059202          2420.393316
# ...

# %% [markdown]
# we have converted the null values to mean of the column

# %%
#ahian check the null values in generation_gwh_2014 column
data['generation_gwh_2014'].isna().sum()
# Out:
# 0

# %% [markdown]
# now generation_gwh_2014 colum have no null values

# %%
#lets the unique values of generation_gwh_2015 column
data['generation_gwh_2015'].unique()
# Out:
# array([           nan, 8.43747000e+02, 5.91637000e+03, 1.20885200e+03,
#        1.52195200e+02, 7.21335200e+02, 1.44434200e+02, 1.64304600e+03,
#        5.62966300e+03, 6.65197300e+02, 8.07681050e+03, 1.11510695e+04,
#        9.09000000e+02, 2.70282320e+03, 1.46500000e+03, 9.86247350e+02,
#        0.00000000e+00, 2.01300000e+03, 2.98513930e+03, 5.53220000e+01,
#        7.41862050e+02, 5.97912500e+03, 1.43795470e+03, 6.18909900e+02,
#        1.96760200e+02, 9.48831000e+02, 5.71607600e+02, 1.06942600e+02,
#        3.96806000e+01, 2.31610720e+03, 2.31626436e+02, 3.26459500e+02,
#        4.05600000e+03, 3.06379000e+02, 1.16531800e+03, 8.29591247e+00,
#        1.29797750e+03, 3.14320500e+02, 5.74131900e+03, 3.98796000e+01,
#        5.86315690e+03, 8.21372500e+01, 6.99485000e+00, 5.65160000e+00,
#        1.55727450e+02, 3.26358400e+03, 6.37138300e+02, 7.35006500e+01,
#        1.95935400e+02, 7.50597200e+03, 1.20406750e+03, 2.80500000e-01,
# ...

# %% [markdown]
# there are lota of unique values generation_gwh_2014 column and as we can see there are null values also so first check the count of null values

# %%
#checking the null values of generation_gwh_2015 column
data['generation_gwh_2015'].isna().sum()
# Out:
# 483

# %% [markdown]
# there are 483 null values sre present i  generation_gwh_2015 column we concert it to mean of the column

# %%
#converting null vaues to the mean of generation_gwh_2015 column
data['generation_gwh_2015']=data['generation_gwh_2015'].fillna(data['generation_gwh_2015'].mean())
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#      geolocation_source  generation_gwh_2013  generation_gwh_2014  \
# 0                     1          2304.059202          2420.393316
# ...

# %% [markdown]
# we have converted the null values to mean of the column

# %%
#agian check the null values in generation_gwh_2015 column
data['generation_gwh_2015'].isna().sum()
# Out:
# 0

# %% [markdown]
# now generation_gwh_2015 colum have no null values

# %%
#lets the unique values of generation_gwh_2015 column
data['generation_gwh_2016'].unique()
# Out:
# array([           nan, 8.86004428e+02, 6.24300000e+03, 1.17576500e+03,
#        6.14213500e+01, 6.75724400e+02, 4.02029750e+02, 1.33809300e+03,
#        1.70100800e+03, 6.70500650e+02, 7.90202160e+03, 1.32273523e+04,
#        6.66420000e+02, 3.51574960e+03, 5.09000000e+02, 2.83200000e+02,
#        0.00000000e+00, 1.51100000e+03, 2.17363720e+03, 1.75018510e+03,
#        6.65983350e+02, 6.34120200e+03, 2.80000000e+03, 9.96373100e+02,
#        1.29033000e+03, 1.66863100e+03, 1.23282490e+03, 1.09181350e+02,
#        5.32126000e+01, 6.77378800e+03, 1.87193669e+02, 1.20903640e+02,
#        4.43242650e+02, 7.17700000e+03, 3.54900000e+02, 1.27499900e+03,
#        1.04689800e+01, 1.33603625e+03, 2.96271200e+02, 5.99932000e+03,
#        2.69247000e+01, 5.14242865e+03, 4.68844000e+01, 4.99230000e+01,
#        1.97308500e+01, 1.73826500e+01, 2.04870500e+01, 3.37910050e+03,
#        9.46871850e+02, 1.01072100e+02, 2.05557050e+02, 5.66607190e+03,
# ...

# %% [markdown]
# there are lota of unique values generation_gwh_2014 column and as we can see there are null values also so first check the count of null values

# %%
#checking the null values of generation_gwh_2015 column
data['generation_gwh_2016'].isna().sum()
# Out:
# 471

# %% [markdown]
# there are 471 null values sre present i generation_gwh_2015 column we concert it to mean of the column

# %%
#converting null vaues to the mean of generation_gwh_2015 column
data['generation_gwh_2016']=data['generation_gwh_2016'].fillna(data['generation_gwh_2016'].mean())
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#      geolocation_source  generation_gwh_2013  generation_gwh_2014  \
# 0                     1          2304.059202          2420.393316
# ...

# %% [markdown]
# we have converted the null values to mean of the column

# %%
#agian check the null values in generation_gwh_2016 column
data['generation_gwh_2016'].isna().sum()
# Out:
# 0

# %% [markdown]
# now generation_gwh_2015 colum have no null values

# %%
#lets the unique values of generation_gwh_2017 column
data['generation_gwh_2017'].unique()
# Out:
# array([           nan, 6.63774500e+02, 5.38557974e+03, 1.14791300e+03,
#        8.96296000e+01, 6.79594950e+02, 4.39372100e+02, 1.56345700e+03,
#        4.35055800e+03, 6.44570950e+02, 7.94074000e+03, 1.53348763e+04,
#        4.30000000e+02, 5.77712000e+03, 3.57000000e+02, 5.40290000e+02,
#        0.00000000e+00, 1.39500000e+03, 2.49417645e+03, 1.81284025e+03,
#        6.38521350e+02, 6.77925600e+03, 2.12068000e+03, 1.46980405e+03,
#        2.01879000e+03, 1.71320100e+03, 5.42643150e+02, 5.58394000e+01,
#        6.84560000e+01, 6.15376000e+03, 1.78106690e+02, 3.47098000e+01,
#        1.58254750e+02, 8.77800000e+03, 1.71355000e+02, 1.43607200e+03,
#        5.85771000e+00, 1.32996675e+03, 3.13594150e+02, 3.73840000e+03,
#        1.56115500e+01, 5.10834990e+03, 4.23372500e+01, 4.32135000e+02,
#        3.74319000e+01, 1.68752000e+01, 3.59090000e+03, 8.87838500e+02,
#        9.66642500e+01, 3.05664000e+02, 6.15962100e+03, 2.26547000e+03,
# ...

# %% [markdown]
# there are lota of unique values generation_gwh_20147column and as we can see there are null values also so first check the count of null values

# %%
#checking the null values of generation_gwh_2017 column
data['generation_gwh_2017'].isna().sum()
# Out:
# 465

# %% [markdown]
# there are 465 null values sre present i generation_gwh_2017 column we concert it to mean of the column

# %%
#converting null vaues to the mean of generation_gwh_2017 column
data['generation_gwh_2017']=data['generation_gwh_2017'].fillna(data['generation_gwh_2017'].mean())
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#      geolocation_source  generation_gwh_2013  generation_gwh_2014  \
# 0                     1          2304.059202          2420.393316
# ...

# %% [markdown]
# we have converted the null values to mean of the column

# %%
#agian check the null values in generation_gwh_2017 column
data['generation_gwh_2017'].isna().sum()
# Out:
# 0

# %% [markdown]
# now generation_gwh_2017 colum have no null values

# %%
#check the uique values of generation_data_source column
data['generation_data_source'].unique()
# Out:
# array([nan, 'Central Electricity Authority'], dtype=object)

# %% [markdown]
# there are only one values central electricity authority and other are nan values

# %%
#lets check for null values in generation_data_source column
data['generation_data_source'].isna().sum()
# Out:
# 458

# %% [markdown]
# there are only one values else are null values we should dropped it beacuse if we fill it then also all the values remain same in the column which is not gonna help to predict

# %%
#dropping generation_data_source column
data=data.drop(columns=['generation_data_source'])
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#      geolocation_source  generation_gwh_2013  generation_gwh_2014  \
# 0                     1          2304.059202          2420.393316
# ...

# %%
#lets check the unique values estimated_generation_gwh column
data['estimated_generation_gwh'].unique()
# Out:
# array([nan])

# %% [markdown]
# there are only null values in this column so better we should deletethis column

# %%
#dropping estimated_generation_gwh column
data=data.drop(columns=['estimated_generation_gwh'])
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#      geolocation_source  generation_gwh_2013  generation_gwh_2014  \
# 0                     1          2304.059202          2420.393316
# ...

# %%
#lets check the datatypes of all the columns 
data.dtypes
# Out:
# capacity_mw            float64
# latitude               float64
# longitude              float64
# primary_fuel             int32
# other_fuel1              int32
# geolocation_source       int32
# generation_gwh_2013    float64
# generation_gwh_2014    float64
# generation_gwh_2015    float64
# generation_gwh_2016    float64
# generation_gwh_2017    float64
# dtype: object

# %% [markdown]
# all are in int or float datatype that means can check the normalization of all the column

# %%
#let check the null values
data.isna().sum()
# Out:
# capacity_mw             0
# latitude               46
# longitude              46
# primary_fuel            0
# other_fuel1             0
# geolocation_source      0
# generation_gwh_2013     0
# generation_gwh_2014     0
# generation_gwh_2015     0
# generation_gwh_2016     0
# generation_gwh_2017     0
# dtype: int64

# %% [markdown]
# there are still two column with null values treat them
#
# latitude and longitude columns

# %%
#lets check the null values of latitude column
data['latitude'].isna().sum()
# Out:
# 46

# %% [markdown]
# 46 null values in latitude column

# %%
#treat null values latitude column
data['latitude']=data['latitude'].fillna(data['latitude'].mean())
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#      geolocation_source  generation_gwh_2013  generation_gwh_2014  \
# 0                     1          2304.059202          2420.393316
# ...

# %%
#again check the null values of latitude column
data['latitude'].isna().sum()
# Out:
# 0

# %% [markdown]
# now there are no null values in latitude column of dayaset

# %%
#lets check null values of longitude column
data['longitude'].isna().sum()
# Out:
# 46

# %% [markdown]
#  there are 46 ull values of longitude column

# %%
#lets treat the longitude column null values
data['longitude']=data['longitude'].fillna(data['longitude'].mean())
data
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            0
# 1           98.0   24.7663    74.6090             1            0
# 2           39.2   21.9038    69.3732             7            0
# 3          135.0   23.8712    91.3602             2            0
# 4         1800.0   21.9603    82.4091             1            3
# ..           ...       ...        ...           ...          ...
# 903       1600.0   16.2949    77.3568             1            3
# 904          3.0   12.8932    78.1654             6            0
# 905         25.5   15.2758    75.5811             7            0
# 906         80.0   24.3500    73.7477             1            0
# 907         16.5    9.9344    77.4768             7            0
#
#      geolocation_source  generation_gwh_2013  generation_gwh_2014  \
# 0                     1          2304.059202          2420.393316
# ...

# %%
#again check the null values of longitude column
data['longitude'].isna().sum()
# Out:
# 0

# %% [markdown]
# there sre no null values in longitude column

# %%
#check the null values in the whole dataset
data.isna().sum()
# Out:
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# other_fuel1            0
# geolocation_source     0
# generation_gwh_2013    0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# dtype: int64

# %% [markdown]
# now there are no null values in datset

# %%
#lets plot a graph to check null values
sns.heatmap(data.isna())
plt.show()

# %% [markdown]
# the heatmap also shows taht there is no null values in datset now

# %%
#new shape of data
data.shape
# Out:
# (908, 11)

# %% [markdown]
# before it was 25 columns and now after deletion or changes it became 11 columns

# %%
#lets check the normalization
plt.figure(figsize=(20,20))
plotnumber=1
for column in data:
    if plotnumber<=11:
        ax=plt.subplot(4,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %% [markdown]
# as we see the data is not normally distributed and there are skewness

# %%
#checking correlation
plt.figure(figsize=(20,20))
data_corr=data.corr()
sns.heatmap(data_corr,annot=True,annot_kws={'size':10})
plt.show()

# %% [markdown]
# there are not much correlation that we dlete any column depend upon the correlation
#
# the highest correlation 77% between capacity_mw and generation_gwh_2017

# %%
#plotting boxplot to check outliers
data.plot(kind='box',subplots = True,layout=(4,3),figsize = (25,25))
plt.show()

# %% [markdown]
# the data are very much skewed im this dataset to remove it proceed with z score

# %%
#now check the skewness
data.skew()
# Out:
# capacity_mw            3.193257
# latitude              -0.147391
# longitude              1.129836
# primary_fuel           0.471141
# other_fuel1            1.369831
# geolocation_source    -2.161710
# generation_gwh_2013    5.241491
# generation_gwh_2014    5.041961
# generation_gwh_2015    5.367370
# generation_gwh_2016    5.071758
# generation_gwh_2017    5.111938
# dtype: float64

# %% [markdown]
# the data is very much skewed in all the columns lets rectify it

# %%
#making the skew less than or equal to 0.55 for better prediction and plotting Normal distribution
skew=('capacity_mw','longitude','other_fuel1','geolocation_source','generation_gwh_2013','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017')
for col in skew:
    if data.skew().loc[col]>0.55:
        data[col]=np.log1p(data[col])

# %%
#again check the skewness
data.skew()
# Out:
# capacity_mw            0.125029
# latitude              -0.147391
# longitude              0.924113
# primary_fuel           0.471141
# other_fuel1            1.365625
# geolocation_source    -2.161710
# generation_gwh_2013   -2.699707
# generation_gwh_2014   -2.589757
# generation_gwh_2015   -2.311574
# generation_gwh_2016   -2.269502
# generation_gwh_2017   -2.278767
# dtype: float64

# %%
#again plot ormalization
plt.figure(figsize=(20,20))
plotnumber=1
for column in data:
    if plotnumber<=11:
        ax=plt.subplot(4,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %% [markdown]
# there are skewness but less

# %%
#plotting boxplot to check outliers
data.plot(kind='box',subplots = True,layout=(4,3),figsize = (25,25))
plt.show()

# %% [markdown]
# again there are outliers to but we can't rid of all beacuse of loss of data

# %% [markdown]
# ###### first regression problem finding capacity_mw

# %%
#split the data
x=data.drop(columns=['capacity_mw'])
y=data['capacity_mw']

# %%
#check shape of x and y 
print('Shape of x is :',x.shape,'\n\n') 
print('Shape of y is :',y.shape,'\n\n')
# Out:
# Shape of x is : (908, 10)
#
#
# Shape of y is : (908,)

# %%
#check relationship between x and y 
plt.figure(figsize=(20,20))
plotnumber=1
for column in x:
    if plotnumber<=16:
        ax=plt.subplot(3,5,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize=10)
        plt.ylabel('capacity_mw')
    plotnumber+=1
plt.show()

# %% [markdown]
# all the columns of x are related to y as we seen in graph

# %%
#importing standard scler to scale the x 
from sklearn.preprocessing import StandardScaler

# %%
s1=StandardScaler()  #instantiate
scaled1=s1.fit_transform(x)
scaled1
# Out:
# array([[ 1.1483961 , -0.9010043 ,  1.22541756, ...,  0.39906319,
#          0.40408601,  0.40311963],
#        [ 0.58673028, -0.59249618, -0.96748576, ...,  0.39906319,
#          0.40408601,  0.40311963],
#        [ 0.11629242, -1.8047639 ,  1.66399822, ...,  0.39906319,
#          0.40408601,  0.40311963],
#        ...,
#        [-0.97298691, -0.37669217,  1.66399822, ...,  0.39906319,
#          0.40408601,  0.40311963],
#        [ 0.51831341, -0.78603384, -0.96748576, ...,  0.39906319,
#          0.40408601,  0.40311963],
#        [-1.85081984,  0.03638046,  1.66399822, ...,  0.39906319,
#          0.40408601,  0.40311963]])

# %% [markdown]
# rhe values of x is scaled

# %%
#import train_test_split
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(scaled1,y,test_size=0.40,random_state=123)

# %% [markdown]
# ###### 1st Model Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.linear_model import Lasso, LassoCV
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn import metrics

# %%
lr=LinearRegression()  #instantiate
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#training score of LinearRegression Model
lr.score(x_train,y_train)
# Out:
# 0.558728049917645

# %% [markdown]
# 55% accuracy of training model of linear regression

# %%
y_pred_lr=lr.predict(x_test)

# %%
lr_score=metrics.r2_score(y_test,y_pred_lr)
print('Accuracy of Linear Rgreesion Model is :',lr_score)
# Out:
# Accuracy of Linear Rgreesion Model is : 0.49899922879152014

# %% [markdown]
# ###### Model Evaluation Linear regression Model

# %%
lr1=mean_absolute_error(y_test,y_pred_lr)
print('Mean Absolute Value of Linear Regression :', lr1)
# Out:
# Mean Absolute Value of Linear Regression : 1.0612722508654098

# %%
lr2=mean_squared_error(y_test,y_pred_lr)
print('Squared mean error Value of Linear Regression :', lr2)
# Out:
# Squared mean error Value of Linear Regression : 1.7210698424474182

# %%
lr3=np.sqrt(mean_squared_error(y_test,y_pred_lr))
print(' root Squared mean error Value of Linear Regression :', lr3)
# Out:
#  root Squared mean error Value of Linear Regression : 1.3118955150649072

# %% [markdown]
# ###### Regularization of Linear regression Model

# %%
LassoCV=LassoCV(alphas=None, max_iter=100,normalize=True)
LassoCV.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-205-d02e2ffc17c6> in <module>
# ----> 1 LassoCV=LassoCV(alphas=None, max_iter=100,normalize=True)
#       2 LassoCV.fit(x_train,y_train)
#
# TypeError: 'LassoCV' object is not callable

# %%
LassoCV.fit(x_train,y_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
#best alpha perimeter
alpha=LassoCV.alpha_
alpha
# Out:
# 0.0012549150893252834

# %%
#use lasso
lasso_reg=Lasso(alpha)
lasso_reg.fit(x_train,y_train)
lasso_reg.score(x_test,y_test)
# Out:
# 0.4996308633057769

# %% [markdown]
# the accuracy of testing data and after regularization the accuracy is same that means model is not over nor under fitted

# %% [markdown]
# ###### Conclusion of Linear Regression Model

# %%
plt.scatter(y_test,y_pred_lr)
plt.xlabel('Actual')
plt.ylabel('Prediction')
plt.show()

# %% [markdown]
# its quite less accurate as we seen in this graph

# %% [markdown]
# ###### 2nd Model KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn=KNeighborsRegressor()  # instantiating
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred_knn=knn.predict(x_test)

# %%
#accuracy of training data
knn.score(x_train,y_train)
# Out:
# 0.8053360965908188

# %% [markdown]
# there is 80% accuracy for knn model in training phase

# %%
#testing score
knn_score=metrics.r2_score(y_test,y_pred_knn)
print('Accuracy of KNeighbors Regressor  Model is :', knn_score)
# Out:
# Accuracy of KNeighbors Regressor  Model is : 0.6403430419608316

# %% [markdown]
# ###### Model Evaluation KNeighbors Regrssion Model

# %%
knn1=mean_absolute_error(y_test,y_pred_knn)
print('Mean Absolute Value of KNeighbors Regression :', knn1)
# Out:
# Mean Absolute Value of KNeighbors Regression : 0.7469688778475516

# %%
knn2=mean_squared_error(y_test,y_pred_knn)
print('Squared mean error Value of KNeighbors Regression :', knn2)
# Out:
# Squared mean error Value of KNeighbors Regression : 1.2355165494346294

# %%
knn3=np.sqrt(mean_squared_error(y_test,y_pred_knn))
print(' root Squared mean error Value of KNeighbors Regression :', knn3)
# Out:
#  root Squared mean error Value of KNeighbors Regression : 1.111537920826199

# %%
#lets check for cross val score=
cross_val_score_knn=cross_val_score(knn,scaled1,y,cv=5).mean()
print('Accuracy after cross validation score is :',cross_val_score_knn)
# Out:
# Accuracy after cross validation score is : 0.6894589330157977

# %% [markdown]
# infact after cross validation the accuracy increased for knn model

# %%
#hyperparameter tuning for knn model

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
#select best features
best_features=SelectKBest(score_func=f_classif,k=9)
fit=best_features.fit(x,y)
data_scores=pd.DataFrame(fit.scores_)
data_columns=pd.DataFrame(x.columns)
#concatenate
feature_scores=pd.concat([data_columns,data_scores], axis=1)
feature_scores.columns=['Feature_Name','score']
print(feature_scores.nlargest(9,'score'))
# Out:
#           Feature_Name     score
# 3          other_fuel1  5.852817
# 4   geolocation_source  3.122351
# 2         primary_fuel  3.048859
# 9  generation_gwh_2017  2.997009
# 8  generation_gwh_2016  2.785944
# 6  generation_gwh_2014  2.414718
# 5  generation_gwh_2013  2.315080
# 7  generation_gwh_2015  2.181607
# 1            longitude  1.529089

# %%
#model building
new_x=data[['other_fuel1','geolocation_source','primary_fuel','generation_gwh_2017','generation_gwh_2016','generation_gwh_2014','generation_gwh_2013','generation_gwh_2015','longitude']]
new_x
# Out:
#      other_fuel1  geolocation_source  primary_fuel  generation_gwh_2017  \
# 0       0.000000                   1             6             7.837063
# 1       0.000000                   2             1             7.837063
# 2       0.000000                   2             7             7.837063
# 3       0.000000                   2             2             6.499448
# 4       1.386294                   2             1             8.591666
# ..           ...                 ...           ...                  ...
# 903     1.386294                   2             1             6.764347
# 904     0.000000                   0             6             7.837063
# 905     0.000000                   2             7             7.837063
# 906     0.000000                   2             1             7.837063
# 907     0.000000                   2             7             7.837063
#
#      generation_gwh_2016  generation_gwh_2014  generation_gwh_2013  \
# ...

# %%
#scalling the new x
scaler=StandardScaler()
scaled_new_x=scaler.fit_transform(new_x)
scaled_new_x
# Out:
# array([[-0.52921943, -1.08428797,  1.22541756, ...,  0.36045375,
#          0.39906319, -0.9010043 ],
#        [-0.52921943,  0.39399052, -0.96748576, ...,  0.36045375,
#          0.39906319, -0.59249618],
#        [-0.52921943,  0.39399052,  1.66399822, ...,  0.36045375,
#          0.39906319, -1.8047639 ],
#        ...,
#        [-0.52921943,  0.39399052,  1.66399822, ...,  0.36045375,
#          0.39906319, -0.37669217],
#        [-0.52921943,  0.39399052, -0.96748576, ...,  0.36045375,
#          0.39906319, -0.78603384],
#        [-0.52921943,  0.39399052,  1.66399822, ...,  0.36045375,
#          0.39906319,  0.03638046]])

# %%
#again instantiating for hyperparameter tuning
knn1=KNeighborsRegressor()
knn1.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred_knn1=knn1.predict(x_test)

# %%
#accuracy of training data
knn1.score(x_train,y_train)
# Out:
# 0.8053360965908188

# %%
#testing score
knn1_score=metrics.r2_score(y_test,y_pred_knn1)
print('Accuracy of KNeighbors Regressor  Model is :', knn1_score)
# Out:
# Accuracy of KNeighbors Regressor  Model is : 0.6403430419608316

# %% [markdown]
# we have selected through different number of features but the accuracy is same

# %% [markdown]
# ###### Conclusion of KNeighbors Model

# %%
plt.scatter(y_test,y_pred_knn1)
plt.xlabel('Actual')
plt.ylabel('Prediction')
plt.show()

# %% [markdown]
# ###### 3rd Model Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor()    #ibstabtiate
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
#checking the score training data
dt.score(x_train,y_train)
# Out:
# 0.9931179825222458

# %% [markdown]
# Accuracy of training data in Decision Tree Regressor model is 99% which is quite good

# %%
y_pred_dt=dt.predict(x_test)

# %%
#testing score
dt_score=metrics.r2_score(y_test,y_pred_dt)
print('Accuracy of Decision Tree Regressor  Model is :', dt_score)
# Out:
# Accuracy of Decision Tree Regressor  Model is : 0.6969748078639237

# %% [markdown]
# ###### Model Evaluation Decision Tree Regrssion Model

# %%
dt1=mean_absolute_error(y_test,y_pred_dt)
print('Mean Absolute Value of Decision Tree Regression :', dt1)
# Out:
# Mean Absolute Value of Decision Tree Regression : 0.7296613102001721

# %%
dt2=mean_squared_error(y_test,y_pred_dt)
print('Squared mean error Value of Decsion Tree Regression :', dt2)
# Out:
# Squared mean error Value of Decsion Tree Regression : 1.0409714907808274

# %%
dt3=np.sqrt(mean_squared_error(y_test,y_pred_dt))
print(' root Squared mean error Value of Decision Tree Regression :', dt3)
# Out:
#  root Squared mean error Value of Decision Tree Regression : 1.0202801040796725

# %%
#checking cross validation for decision tree regression model
cross_val_score_dt=cross_val_score(knn,scaled1,y,cv=5).mean()
print('Accuracy after cross validation score is :',cross_val_score_dt)
# Out:
# Accuracy after cross validation score is : 0.6894589330157977

# %% [markdown]
# cross validation scpre is decreased by the accuracy that deciisontree regression model gives
#
# Decision Tree Regression accuracy== 69%
#
# cross val score of decision tree regression --68%

# %% [markdown]
# ###### Hyperparameter Tuning for Decision Tree Regression Model

# %%
grid_params1={'max_depth':[1,2,3,4,5,6,7,8],
              'min_samples_leaf':[1,2,3,4,5,6,7,8],
               'max_features':['auto','log2','sqrt',None],
               'max_leaf_nodes':[1,2,3,4,5,6,7,8]}
print(grid_params1)
# Out:
# {'max_depth': [1, 2, 3, 4, 5, 6, 7, 8], 'min_samples_leaf': [1, 2, 3, 4, 5, 6, 7, 8], 'max_features': ['auto', 'log2', 'sqrt', None], 'max_leaf_nodes': [1, 2, 3, 4, 5, 6, 7, 8]}

# %%
grid_dt=GridSearchCV(dt,param_grid=grid_params1,cv=3,verbose=3)

# %%
grid_dt.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 2048 candidates, totalling 6144 fits
# [CV 1/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=1; total time=   0.0s
# [CV 2/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=1; total time=   0.0s
# [CV 3/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=1; total time=   0.0s
# [CV 1/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=2; total time=   0.0s
# [CV 2/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=2; total time=   0.0s
# [CV 3/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=2; total time=   0.0s
# [CV 1/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=3; total time=   0.0s
# [CV 2/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=3; total time=   0.0s
# ...

# %%
# best hyperparameters 
grid_dt.best_params_
# Out:
# {'max_depth': 4,
#  'max_features': 'log2',
#  'max_leaf_nodes': 7,
#  'min_samples_leaf': 1}

# %%
#best aparameter model score
grid_dt.best_score_
# Out:
# 0.7703907542493381

# %% [markdown]
# 76 % score of best parameter of decision tree regression

# %%
#traininf decision tree with hyperparameter feature
dt_hyp=DecisionTreeRegressor(max_depth = 6,max_features= 'sqrt',max_leaf_nodes = 8,min_samples_leaf= 5)

# %%
#noe fitting decsiontree hyperparameter
dt_hyp.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=6, max_features='sqrt', max_leaf_nodes=8,
#                       min_samples_leaf=5)

# %%
y_pred_dt1=dt_hyp.predict(x_test)

# %%
#trainig accuracy of hyperparameter of Dt model
dt_hyp.score(x_train,y_train)
# Out:
# 0.7577070578965543

# %%
#testing score of dt after hyperparameter tuning
dt_hyp_score=metrics.r2_score(y_test,y_pred_dt1)
print('Accuracy of Decision Tree Regressor  Model is :', dt_hyp_score)
# Out:
# Accuracy of Decision Tree Regressor  Model is : 0.7422279059817041

# %% [markdown]
# decsion Tree Regression model accuracy increased from 68 to 74 % through hyperparameter tuning
#
# before Hyperparameter==68%
#
# after hyperparameter==71%

# %% [markdown]
# ###### Conclusion Of Decision Tree Regression Model

# %%
plt.scatter(y_test,y_pred_dt1)
plt.xlabel('Actual')
plt.ylabel('Prediction')
plt.show()

# %% [markdown]
# ###### 4th Model Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()  #instantiate
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
#training score of Random Forest regressor model
rfr.score(x_train,y_train)
# Out:
# 0.9697425311190411

# %%
y_pred_rfr=rfr.predict(x_test)

# %%
#checking testing score of Random forest regressor model
rfr_score=metrics.r2_score(y_test,y_pred_rfr)
print('Accuracy of RandomForest Regressor  Model is :', rfr_score)
# Out:
# Accuracy of RandomForest Regressor  Model is : 0.7888194630947554

# %% [markdown]
# ###### hyperparameter tuning for Random Forest Regressor

# %%
params2={'n_estimators':[10,20,30,40],
         'max_features':['auto','sqrt'],
         'max_depth':[1,2,3,4,5,6,7,8],
         'min_samples_split':[1,2,3],
         'min_samples_leaf':[1,2,4],
         'bootstrap': [True, False]
        }
print(params2)
# Out:
# {'n_estimators': [10, 20, 30, 40], 'max_features': ['auto', 'sqrt'], 'max_depth': [1, 2, 3, 4, 5, 6, 7, 8], 'min_samples_split': [1, 2, 3], 'min_samples_leaf': [1, 2, 4], 'bootstrap': [True, False]}

# %%
grid_rfr=GridSearchCV(rfr,param_grid=params2,cv=5,verbose=3)

# %%
grid_rfr.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 1152 candidates, totalling 5760 fits
# [CV 1/5] END bootstrap=True, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=10; total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=10; total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=10; total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=10; total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=10; total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=1, max_features=auto, min_samples_leaf=1, min_samples_split=1, n_estimators=20; total time=   0.0s
# ...

# %%
#best parameters for RandomForestRegressor model
grid_rfr.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 8,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 30}

# %%
#best score of params
grid_rfr.best_score_
# Out:
# 0.8275909365207372

# %%
#train the hyperparameter params of Random Forest Regressor
rfr_hyp=RandomForestRegressor(bootstrap=True,max_depth= 8,max_features= 'sqrt',min_samples_leaf= 1,min_samples_split= 2,n_estimators= 30)

# %%
#train the hyperparameter of Random forest Regressor
rfr_hyp.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=8, max_features='sqrt', n_estimators=30)

# %%
y_pred_rfr_hyp=rfr_hyp.predict(x_test)

# %%
#training score of Random Forest Regressor with best parameters
rfr_hyp.score(x_train,y_train)
# Out:
# 0.9074933298806055

# %% [markdown]
# 90% accuracy of Random Forest Regressor Model after Hyperparameter Tuning

# %%
#tetsing score of Random Forest Regressor
rfr_hyp_score=metrics.r2_score(y_test,y_pred_rfr_hyp)
print('Accuracy of RandomForest Regressor  Model is :', rfr_hyp_score)
# Out:
# Accuracy of RandomForest Regressor  Model is : 0.8011019298895121

# %% [markdown]
# ###### Model Evaluation of Random Forest Regressor Model

# %%
rfr1=mean_absolute_error(y_test,y_pred_rfr_hyp)
print('Mean Absolute Value of Random Forest Regression :', rfr1)
# Out:
# Mean Absolute Value of Random Forest Regression : 0.5945007382167814

# %%
rfr2=mean_squared_error(y_test,y_pred_rfr_hyp)
print('Squared mean error Value of Random Forest Regression :', rfr2)
# Out:
# Squared mean error Value of Random Forest Regression : 0.6832673517895754

# %%
rfr3=np.sqrt(mean_squared_error(y_test,y_pred_rfr_hyp))
print(' root Squared mean error Value of Random Forest Regression :', rfr3)
# Out:
#  root Squared mean error Value of Random Forest Regression : 0.8265998740561091

# %% [markdown]
# ###### conclusion of Random Forest regression Model

# %%
plt.scatter(y_test,y_pred_rfr_hyp)
plt.xlabel('Actual')
plt.ylabel('Prediction')
plt.show()

# %% [markdown]
# quite accurate of Random Forest Regression Model

# %% [markdown]
# ###### All the score of all the models

# %% [markdown]
# 1. Linear Model                             49% accuracy          after Lasso same 49%
# 2. KNeighbors Model                         64%accuracy           after Tuning same 64%
# 3. Decision Tree Regression Model           68% after after cv    after tuning 74 % accuracy
# 4. Random Forest Regression Model           78% after cv          after Tuning 80%

# %% [markdown]
# Random Forest Model suites best for this problem

# %% [markdown]
# ### 2nd Regression

# %% [markdown]
# ###### find Primary_fuel

# %%
#splitting x and y 
x1=data.drop(columns=['primary_fuel'])
y1=data['primary_fuel']

# %%
#scaling the data for new regression
s2=StandardScaler()  # instantiate
scaled2=s2.fit_transform(x1)
scaled2
# Out:
# array([[-1.6340626 ,  1.1483961 , -0.9010043 , ...,  0.39906319,
#          0.40408601,  0.40311963],
#        [ 0.16015781,  0.58673028, -0.59249618, ...,  0.39906319,
#          0.40408601,  0.40311963],
#        [-0.32364638,  0.11629242, -1.8047639 , ...,  0.39906319,
#          0.40408601,  0.40311963],
#        ...,
#        [-0.54734828, -0.97298691, -0.37669217, ...,  0.39906319,
#          0.40408601,  0.40311963],
#        [ 0.05243519,  0.51831341, -0.78603384, ...,  0.39906319,
#          0.40408601,  0.40311963],
#        [-0.77009551, -1.85081984,  0.03638046, ...,  0.39906319,
#          0.40408601,  0.40311963]])

# %%
#train test split
x1_train,x1_test,y1_train,y1_test=train_test_split(scaled2,y1,test_size=0.40,random_state=123)

# %%
#shape of tarining and testing data
print(x1_train.shape)
print(x1_test.shape)
print(y1_train.shape)
print(y1_test.shape)
# Out:
# (544, 10)
# (364, 10)
# (544,)
# (364,)

# %% [markdown]
# ###### 1st model Linear Regression

# %%
lr=LinearRegression()  #instantiate
lr.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
#training score of LinearRegression Model
lr.score(x1_train,y1_train)
# Out:
# 0.44639580876347473

# %% [markdown]
# 44% accuracy of training model of linear regression

# %%
y1_pred_lr=lr.predict(x1_test)

# %%
lr_score=metrics.r2_score(y1_test,y1_pred_lr)
print('Accuracy of Linear Rgreesion Model is :',lr_score)
# Out:
# Accuracy of Linear Rgreesion Model is : 0.40929874121325494

# %% [markdown]
# ###### Model Evaluation for Linear Regression

# %%
lr1=mean_absolute_error(y1_test,y1_pred_lr)
print('Mean Absolute Value of Linear Regression :', lr1)
# Out:
# Mean Absolute Value of Linear Regression : 1.2139885285888723

# %%
lr2=mean_squared_error(y1_test,y1_pred_lr)
print('Squared mean error Value of Linear Regression :', lr2)
# Out:
# Squared mean error Value of Linear Regression : 3.0774592215545433

# %%
lr3=np.sqrt(mean_squared_error(y1_test,y1_pred_lr))
print(' root Squared mean error Value of Linear Regression :', lr3)
# Out:
#  root Squared mean error Value of Linear Regression : 1.7542688566905995

# %% [markdown]
# ###### Regularization of Linear Model regression

# %%
LassoCV1=LassoCV(alphas=None, max_iter=100,normalize=True)
LassoCV1.fit(x1_train,y1_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-204-4eb94d7370c1> in <module>
# ----> 1 LassoCV1=LassoCV(alphas=None, max_iter=100,normalize=True)
#       2 LassoCV1.fit(x1_train,y1_train)
#
# TypeError: 'LassoCV' object is not callable

# %%
LassoCV1.fit(x1_train,y1_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-206-1e8f075b84ed> in <module>
# ----> 1 LassoCV1.fit(x1_train,y1_train)
#
# NameError: name 'LassoCV1' is not defined

# %%
#best alpha perimeter
alpha=LassoCV1.alpha_
alpha
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-207-847883a9e932> in <module>
#       1 #best alpha perimeter
# ----> 2 alpha=LassoCV1.alpha_
#       3 alpha
#
# NameError: name 'LassoCV1' is not defined

# %%
#use lasso
lasso_reg=Lasso(alpha)
lasso_reg.fit(x1_train,y1_train)
lasso_reg.score(x1_test,y1_test)
# Out:
# 0.4093784888580093

# %% [markdown]
# the accuracy of testing data and after regularization the accuracy is same that means model is not over nor under fitted

# %% [markdown]
# ###### conclusion of Linear Model

# %%
plt.scatter(y1_test,y1_pred_lr)
plt.xlabel('Actual')
plt.ylabel('Prediction')
plt.show()

# %% [markdown]
# The accuracy is very low thats why it won't follow the pattern

# %% [markdown]
# ###### 2nd Model KNN

# %%
knn=KNeighborsRegressor()  # instantiating
knn.fit(x1_train,y1_train)
# Out:
# KNeighborsRegressor()

# %%
y1_pred_knn=knn.predict(x1_test)

# %%
#trainig score of Knn Model
knn.score(x1_train,y1_train)
# Out:
# 0.7547622985243597

# %% [markdown]
# training score of KNN model is 75%

# %%
#testing score
knn_score=metrics.r2_score(y1_test,y1_pred_knn)
print('Accuracy of KNeighbors Regressor  Model is :', knn_score)
# Out:
# Accuracy of KNeighbors Regressor  Model is : 0.5716052691432354
