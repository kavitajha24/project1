# %%
#importing necesarry libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import zipfile

# %%
#raw link of avacado zipped dataset
filelink='https://github.com/dsrscientist/IBM_HR_Attrition_Rate_Analytics/blob/master/ibm-hr-analytics-employee-attrition-performance.zip?raw=true'

# %%
#importing request and input output to give request to copy directories
import requests,io

# %%
getfolder=requests.get(filelink)

# %%
unzipfolder=zipfile.ZipFile(io.BytesIO(getfolder.content))

# %%
unzipfolder.extractall('./newhrurl')

# %%
import os

# %%
root='./newhrurl'
for path,subdir,files in os.walk(root):
    for name in files:
        print(os.path.join(path,name))
# Out:
# ./newhrurl\WA_Fn-UseC_-HR-Employee-Attrition.csv

# %%
data=pd.read_csv('./newhrurl\WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#check all the columns tht availbale in dataset
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#summarize the dataset
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#checking the inforamtion of dataset weather it has any null values of types of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# as we there is list of every column in dataset with their respective informations

# %%
#checking datatypes of dataset
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# types of datas the columns helds in

# %%
#checking null values
data.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# there are no null values is any of the columns

# %%
#cheking null values through heatmap
sns.heatmap(data.isna())
plt.title('Null Vlaues')
plt.show()

# %% [markdown]
# all the values are filled ans no null values are present in dataset

# %% [markdown]
# #### converting columns(categorical or object) to numerical form

# %% [markdown]
# ###### Attrition Column

# %%
#check the unique vakues in Attition column
data['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# there are only two values yes or no

# %%
#chaeck the count of values in Attrtion column
data['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# these the counts of yes and no in attrition column

# %%
#plotting countplot to check count of attrition column values
sns.countplot(data['Attrition'])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
#noe we will encode the values of attrition column into numeric values
l1=LabelEncoder()  #instantiate label encoder
df1=l1.fit_transform(data['Attrition'])
data['Attrition']=df1
data
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# we have converted the categoracl data into numric of atrittion column
#
# yes-1
# No-0

# %% [markdown]
# ###### Business Travel Coulmn

# %%
#checking the unique values that the column have
data['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
#checking the count of each values in Business travel column
data['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
#plotting count for same value counts of Business Travel column
sns.countplot(data['BusinessTravel'])
plt.show()

# %%
data
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#converting onject type column in  numerical column of BusinessTravel
l2=LabelEncoder()  #again insatantiating
df2=l2.fit_transform(data['BusinessTravel'])
data['BusinessTravel']=df2
data
# Out:
#       Age  Attrition  BusinessTravel  DailyRate              Department  \
# 0      41          1               2       1102                   Sales
# 1      49          0               1        279  Research & Development
# 2      37          1               2       1373  Research & Development
# 3      33          0               1       1392  Research & Development
# 4      27          0               2        591  Research & Development
# ...   ...        ...             ...        ...                     ...
# 1465   36          0               1        884  Research & Development
# 1466   39          0               2        613  Research & Development
# 1467   27          0               2        155  Research & Development
# 1468   49          0               1       1023                   Sales
# 1469   34          0               2        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# we ahve converted the values of Business travel column
#
# non_travel=0
#
# travel_frequently= 1
#
# travel_rarely=2

# %% [markdown]
# #### Deparment Column

# %%
#check the unique values that department column have
data['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %% [markdown]
# there are three unique values that department column have abd that avlues are
#
# sales,  Research and Development,  Human Resources

# %%
#checking the number of each unique valyes in dadaset of Department column
data['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
#plottong graph for unique value counts of Department column
sns.countplot(data['Department'])
plt.show()

# %%
#converting onject type column in  numerical column of Department
l3=LabelEncoder()  #again insatantiating
df3=l2.fit_transform(data['Department'])
data['Department']=df3
data
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %% [markdown]
# we have converted the Department columns values
#
# Humanresources=0
#
# Research and Development-1
#
# Sales-2

# %% [markdown]
# ##### Education Field column

# %%
#checking the unique values in Education feild columm
data['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
#counting the vakues of Education Field column
data['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
#plotting the countplot of education feild column
sns.countplot(data['EducationField'])
plt.show()

# %%
#converting onject type column in  numerical column of Education Field
l4=LabelEncoder()  #again insatantiating
df4=l4.fit_transform(data['EducationField'])
data['EducationField']=df4
data
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
#checking Unique values of Gender column
data['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
#checking number of male and female in gender column
data['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
#plotting coutplot for gender column
sns.countplot(data['Gender'])
plt.show()

# %%
#converting onject type column in  numerical column of Gender
l5=LabelEncoder()  #again insatantiating
df5=l5.fit_transform(data['Gender'])
data['Gender']=df5
data['Gender']
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 1465    1
# 1466    1
# 1467    1
# 1468    1
# 1469    1
# Name: Gender, Length: 1470, dtype: int32

# %% [markdown]
# we have converted
#
# female-0
#
# male-1

# %% [markdown]
# ##### JobRole column

# %%
data['JobRole']
# Out:
# 0                 Sales Executive
# 1              Research Scientist
# 2           Laboratory Technician
# 3              Research Scientist
# 4           Laboratory Technician
#                   ...
# 1465        Laboratory Technician
# 1466    Healthcare Representative
# 1467       Manufacturing Director
# 1468              Sales Executive
# 1469        Laboratory Technician
# Name: JobRole, Length: 1470, dtype: object

# %%
#checking the unique values in Job role column
data['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
#counting of eacj values in job role column
data['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
#plotting for job role values column
sns.countplot(data['JobRole'])
plt.xticks(rotation=90)
plt.show()

# %%
#converting onject type column in  numerical column of Gender
l6=LabelEncoder()  #again insatantiating
df6=l6.fit_transform(data['JobRole'])
data['JobRole']=df6
data['JobRole']
# Out:
# 0       7
# 1       6
# 2       2
# 3       6
# 4       2
#        ..
# 1465    2
# 1466    0
# 1467    4
# 1468    7
# 1469    2
# Name: JobRole, Length: 1470, dtype: int32

# %% [markdown]
# converted the object type into int datatype

# %% [markdown]
# ##### Marital Status column

# %%
data['MaritalStatus']
# Out:
# 0        Single
# 1       Married
# 2        Single
# 3       Married
# 4       Married
#          ...
# 1465    Married
# 1466    Married
# 1467    Married
# 1468    Married
# 1469    Married
# Name: MaritalStatus, Length: 1470, dtype: object

# %%
#checking the unique values of this Marital statys column
data['MaritalStatus'].unique()
# Out:
# array(['Single', 'Married', 'Divorced'], dtype=object)

# %%
#checking numbrs of eacj unique values of Marital sattus column
data['MaritalStatus'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
#plotting countplot for Marital status column
sns.countplot(data['MaritalStatus'])
plt.show()

# %%
#converting onject type column in  numerical column of Marital Status
l7=LabelEncoder()  #again insatantiating
df7=l7.fit_transform(data['MaritalStatus'])
data['MaritalStatus']=df7
data['MaritalStatus']
# Out:
# 0       2
# 1       1
# 2       2
# 3       1
# 4       1
#        ..
# 1465    1
# 1466    1
# 1467    1
# 1468    1
# 1469    1
# Name: MaritalStatus, Length: 1470, dtype: int32

# %% [markdown]
# converted the column datatype
#
# Divorced-0
#
# maried=1
#
# single-2

# %% [markdown]
# ###### Over18 column

# %%
# weather the employee is over 18 or not
data['Over18']
# Out:
# 0       Y
# 1       Y
# 2       Y
# 3       Y
# 4       Y
#        ..
# 1465    Y
# 1466    Y
# 1467    Y
# 1468    Y
# 1469    Y
# Name: Over18, Length: 1470, dtype: object

# %%
#checking the uunique values of over 18 column
data['Over18'].unique()
# Out:
# array(['Y'], dtype=object)

# %% [markdown]
# there is only one type of data value in it and that probably not much helpful while building model so we should drop this column

# %%
#dropping the Over18 column'
data=data.drop(columns=['Over18'])
data
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %% [markdown]
# ##### OverTime column

# %%
data['OverTime']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467    Yes
# 1468     No
# 1469     No
# Name: OverTime, Length: 1470, dtype: object

# %%
#checking the unique values of OverTime columm
data['OverTime'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
#countig the numbers of each unique value in OverTime column
data['OverTime'].value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
#plotting countplot for samr
sns.countplot(data['OverTime'])
plt.show()

# %%
#converting onject type column in  numerical column of Over time
l8=LabelEncoder()  #again insatantiating
df8=l8.fit_transform(data['OverTime'])
data['OverTime']=df8
data['OverTime']
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    1
# 1468    0
# 1469    0
# Name: OverTime, Length: 1470, dtype: int32

# %%
#again the datatypes of all the columns
data.dtypes
# Out:
# Age                         int64
# Attrition                   int32
# BusinessTravel              int32
# DailyRate                   int64
# Department                  int32
# DistanceFromHome            int64
# Education                   int64
# EducationField              int32
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                      int32
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int32
# JobSatisfaction             int64
# MaritalStatus               int32
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# OverTime                    int32
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# StockOptionLevel            int64
# ...

# %% [markdown]
# now all the columns are sucessfully converted into int datatype

# %%
#dropping columns which are less usefull
data=data.drop(columns=['EmployeeNumber','DistanceFromHome'])
data
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  Education  \
# 0      41          1               2       1102           2          2
# 1      49          0               1        279           1          1
# 2      37          1               2       1373           1          2
# 3      33          0               1       1392           1          4
# 4      27          0               2        591           1          1
# ...   ...        ...             ...        ...         ...        ...
# 1465   36          0               1        884           1          2
# 1466   39          0               2        613           1          1
# 1467   27          0               2        155           1          3
# 1468   49          0               1       1023           2          3
# 1469   34          0               2        628           1          3
#
#       EducationField  EmployeeCount  EnvironmentSatisfaction  Gender  ...  \
# ...

# %%
#normalization
plt.figure(figsize=(20,20))
plotnumber=1
for column in data:
    if plotnumber<=32:
        ax=plt.subplot(8,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %% [markdown]
# because maximum of columns are havig 1 and 2 and 0 vlalues thats why the normalize are not well distributed

# %% [markdown]
# #### checking Correlation

# %%
data_corr=data.corr()
plt.figure(figsize=(50,50))
sns.heatmap(data_corr,annot=True,annot_kws={'size':40})
plt.show()

# %%
#plotting boxplot to check outliers
data.plot(kind='box',subplots = True,layout=(8,4),figsize = (25,25))
plt.show()

# %% [markdown]
# ##### splitting feature and target variable

# %%
x=data.drop(columns=['Attrition','StandardHours'])
y=data['Attrition']

# %%
#shape of x and y 
print('Shape of x is :', x.shape)
print('Shape of x is :', y.shape)
# Out:
# Shape of x is : (1470, 30)
# Shape of x is : (1470,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaled_x=scaler.fit_transform(x)
scaled_x.shape[1]
# Out:
# 30

# %% [markdown]
# ###### variance inflation factor

# %%
#importing variance inflation factor
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(scaled_x,i) for i in range(scaled_x.shape[1])]

# %%
vif['Features']=x.columns
vif
# Out:
#           VIF                  Features
# 0    2.053914                       Age
# 1    1.016012            BusinessTravel
# 2    1.023941                 DailyRate
# 3    1.941795                Department
# 4    1.062995                 Education
# 5    1.016142            EducationField
# 6         NaN             EmployeeCount
# 7    1.017214   EnvironmentSatisfaction
# 8    1.019383                    Gender
# 9    1.020146                HourlyRate
# 10   1.020752            JobInvolvement
# 11  11.778556                  JobLevel
# 12   1.893944                   JobRole
# 13   1.020669           JobSatisfaction
# 14   1.840378             MaritalStatus
# 15  11.000432             MonthlyIncome
# 16   1.014711               MonthlyRate
# 17   1.260525        NumCompaniesWorked
# 18   1.027952                  OverTime
# 19   2.518833         PercentSalaryHike
# 20   2.519157         PerformanceRating
# 21   1.020673  RelationshipSatisfaction
# ...

# %%
#checking the skewness of data
data.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# Education                  -0.289681
# EducationField              0.550371
# EmployeeCount               0.000000
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StandardHours               0.000000
# StockOptionLevel            0.968980
# ...

# %%
#making the skew less than or equal to 0.55 for better prediction and plotting Normal distribution
skew=('MonthlyIncome','NumCompaniesWorked','YearsSinceLastPromotion','TotalWorkingYears','JobLevel')
for col in skew :
    if data.skew().loc[col]>0.55:
        data[col] = np.log1p(data[col])

# %%
data.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# Education                  -0.289681
# EducationField              0.550371
# EmployeeCount               0.000000
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.448133
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               0.286448
# MonthlyRate                 0.018578
# NumCompaniesWorked          0.092896
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StandardHours               0.000000
# StockOptionLevel            0.968980
# ...

# %%
#normalization
plt.figure(figsize=(20,20))
plotnumber=1
for column in data:
    if plotnumber<=32:
        ax=plt.subplot(8,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %%
#plotting the boxplot of each column to check the outliers 
data.plot(kind='box',subplots = True,layout=(8,4),figsize = (15,10))
# Out:
# Age                            AxesSubplot(0.125,0.799681;0.168478x0.0803191)
# Attrition                   AxesSubplot(0.327174,0.799681;0.168478x0.0803191)
# BusinessTravel              AxesSubplot(0.529348,0.799681;0.168478x0.0803191)
# DailyRate                   AxesSubplot(0.731522,0.799681;0.168478x0.0803191)
# Department                     AxesSubplot(0.125,0.703298;0.168478x0.0803191)
# Education                   AxesSubplot(0.327174,0.703298;0.168478x0.0803191)
# EducationField              AxesSubplot(0.529348,0.703298;0.168478x0.0803191)
# EmployeeCount               AxesSubplot(0.731522,0.703298;0.168478x0.0803191)
# EnvironmentSatisfaction        AxesSubplot(0.125,0.606915;0.168478x0.0803191)
# Gender                      AxesSubplot(0.327174,0.606915;0.168478x0.0803191)
# HourlyRate                  AxesSubplot(0.529348,0.606915;0.168478x0.0803191)
# JobInvolvement              AxesSubplot(0.731522,0.606915;0.168478x0.0803191)
# ...

# %% [markdown]
# now there are less skewness

# %% [markdown]
# ##### relationship between x and y

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for column in x:
    if plotnumber<=20:
        ax=plt.subplot(4,5,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize=10)
        plt.ylabel('wins')
    plotnumber+=1
plt.show()

# %% [markdown]
# as now we have less skewness so ready for model building

# %%
#train and testing phase
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(scaled_x,y,test_size=0.35,random_state=123)

# %%
#shape of x_train,y_train
print('Shape of x_train is:', x_train.shape)
print('Shape of y_train is:', y_train.shape)
print('Shape of x_test is:', x_test.shape)
print('Shape of y_test is:', y_test.shape)
# Out:
# Shape of x_train is: (955, 30)
# Shape of y_train is: (955,)
# Shape of x_test is: (515, 30)
# Shape of y_test is: (515,)

# %% [markdown]
# ###### model1
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve
from sklearn.model_selection import GridSearchCV

# %%
lr=LogisticRegression()  #instantiate
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lr=lr.predict(x_test)

# %%
train1=lr.score(x_train,y_train)
print('Accuracy of training data of logistic regression is :',train1)
# Out:
# Accuracy of training data of logistic regression is : 0.8607329842931937

# %%
accuracy_score(y_test,y_pred_lr)
# Out:
# 0.9029126213592233

# %% [markdown]
# accraccy of testing data of logistic regression is 90 %

# %%
print(classification_report(y_test,y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       445
#            1       0.81      0.37      0.51        70
#
#     accuracy                           0.90       515
#    macro avg       0.86      0.68      0.73       515
# weighted avg       0.90      0.90      0.89       515

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
lr=LogisticRegression()
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()
kn=KNeighborsClassifier()

# %%
clf=RandomForestClassifier()
params={'n_estimators':[13,15],
       'criterion':['entropy'],
       'max_depth':[10,15],
       'min_samples_split':[10,11],
       'min_samples_leaf':[5,6]
       }

grd=GridSearchCV(clf,param_grid=params)
grd.fit(x_train,y_train)
print('best_params=>',grd.best_params_)

clf=grd.best_estimator_

clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)

rf_conf_mat=confusion_matrix(y_test,y_pred)

print('\ncon_mat','\n',rf_conf_mat)
print('\n Accuracy rf normal',accuracy_score(y_test,y_pred))
# Out:
# best_params=> {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 5, 'min_samples_split': 11, 'n_estimators': 15}
#
# con_mat
#  [[443   2]
#  [ 56  14]]
#
#  Accuracy rf normal 0.887378640776699

# %% [markdown]
# ##### Lets plot ROC AUC Curve to choose best model

# %%
lr=LogisticRegression()
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()
kn=KNeighborsClassifier()

# %%
#training with all classifier
lr.fit(x_train,y_train)
dt.fit(x_train,y_train)
rf.fit(x_train,y_train)
kn.fit(x_train,y_train)

print('All Models are trained')
# Out:
# All Models are trained

# %%
#all models scores are captured
lr.score(x_test,y_test)
dt.score(x_test,y_test)
rf.score(x_test,y_test)
kn.score(x_test,y_test)

print('All Models test score captured')
# Out:
# All Models test score captured

# %% [markdown]
# ##### ets check ROC AUC curve for the fitted model

# %%
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.metrics import plot_roc_curve
disp=plot_roc_curve(dt,x_test,y_test)
plot_roc_curve(lr,x_test,y_test,ax=disp.ax_)
plot_roc_curve(kn,x_test,y_test,ax=disp.ax_)
plot_roc_curve(rf,x_test,y_test,ax=disp.ax_)
plt.legend(prop={'size':11},loc='lower right')
plt.show()

# %% [markdown]
# random forest gives maximum score for testing data that is 83 % even after hyperaramerter or cross validation

# %%
import pickle

# %%
filname='hr.pkl'

# %%
pickle.dump=(rf,open('hr.pkl','wb'))
