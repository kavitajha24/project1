# %%
#importing necessary Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#load the dataset
url='https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv'
data=pd.read_csv(url)
data
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
#shape of tha data=
data.shape
# Out:
# (1000, 40)

# %% [markdown]
# there are
#
# 1000- rows
#
# 40- columns

# %%
#all the column names that are present in dataset
data.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %%
#some information about datset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %% [markdown]
# it gives us datatypes or null values that are present in the dataset and we see there are lot of null values present in maximum number of columns

# %%
#lets check one by one null values in each column
data.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
#dropping _c39 column beacuse all the null values are in _c39
data=data.drop(columns=['_c39'])
data
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %% [markdown]
# dropped the _c39 column because they only have null values in this column so we dropped it

# %%
#datatypes of each column i.e what type of data column held in 
data.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# ...

# %%
#lets summarize the dataset
data.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %% [markdown]
# ###### unique values of each columns
#
# lets check the unique values of all columns to see weather its useful or not oe wether we can convert it into numeric or not

# %% [raw]
# months_as_customer Column

# %%
#check the unique values of months_as_customer  column
data['months_as_customer'].unique()
# Out:
# array([328, 228, 134, 256, 137, 165,  27, 212, 235, 447,  60, 121, 180,
#        473,  70, 140, 160, 196, 460, 217, 370, 413, 237,   8, 257, 202,
#        224, 241,  64, 166, 155, 114, 149, 147,  62, 289, 431, 199,  79,
#        116,  37, 106, 269, 265, 163, 355, 175, 192, 430,  91, 223, 195,
#         22, 439,  94,  11, 151, 154, 245, 119, 215, 295, 254, 107, 478,
#        128, 338, 271, 222, 120, 270, 319, 194, 227, 244,  78, 200, 284,
#        275, 153,  31,  41, 127,  61, 207, 219,  80, 325,  29, 239, 279,
#        350, 464, 118, 298,  87, 261, 453, 210, 168, 390, 258, 225, 164,
#        255, 206, 203, 211, 274,  81, 280, 112,  24,  93, 171, 124, 287,
#        122, 398, 214, 209,  82, 193, 288, 104, 101, 375, 461, 428,  45,
#        136, 216, 278, 108,  14, 276,  47,  73, 294, 324,  53, 426, 111,
#         86, 296, 125, 177, 238, 449, 252, 359,  19, 285,  30, 342, 468,
#        343, 404,  63, 335, 142, 272,  69,  38, 281, 246, 330, 362, 371,
# ...

# %%
#checkin null values in months_as_customer  column
data['months_as_customer'].isna().sum()
# Out:
# 0

# %% [markdown]
# There is no null values in months_as_customer  column and also its in int datatype so we dont need to change the datatype also just be as it is

# %%
#lets check the value count of months_as_customer  column
data['months_as_customer'].value_counts()
# Out:
# 194    8
# 254    7
# 210    7
# 101    7
# 140    7
#       ..
# 312    1
# 62     1
# 309    1
# 308    1
# 0      1
# Name: months_as_customer, Length: 391, dtype: int64

# %%
#lets plot the countplot of months_as_customer  column
plt.figure(figsize=(30,30))
sns.countplot(data['months_as_customer'])
plt.xticks(rotation=90)
plt.show()

# %% [raw]
# Age Column

# %%
#lets check the null values in Age column
data['age'].isna().sum()
# Out:
# 0

# %% [markdown]
# There are no null values in Age column so we proceed to this column

# %% [markdown]
# policy_number Column

# %%
#lets check the null values in policy_number column
data['policy_number'].isna().sum()
# Out:
# 0

# %% [markdown]
# but we can drop this beacause the policy number are just the unique number prvided to the customer by the company and it does not contribute much in this

# %%
#dropping policy_number column
data=data.drop(columns=['policy_number'])
data
# Out:
#      months_as_customer  age policy_bind_date policy_state policy_csl  \
# 0                   328   48       17-10-2014           OH    250/500
# 1                   228   42       27-06-2006           IN    250/500
# 2                   134   29       06-09-2000           OH    100/300
# 3                   256   41       25-05-1990           IL    250/500
# 4                   228   44       06-06-2014           IL   500/1000
# ..                  ...  ...              ...          ...        ...
# 995                   3   38       16-07-1991           OH   500/1000
# 996                 285   41       05-01-2014           IL    100/300
# 997                 130   34       17-02-2003           OH    250/500
# 998                 458   62       18-11-2011           IL   500/1000
# 999                 456   60       11-11-1996           OH    250/500
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# ...

# %% [raw]
# policy_bind_date Column

# %%
#dropping the policy_bind_date column
data=data.drop(columns=['policy_bind_date'])
data
# Out:
#      months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                   328   48           OH    250/500               1000
# 1                   228   42           IN    250/500               2000
# 2                   134   29           OH    100/300               2000
# 3                   256   41           IL    250/500               2000
# 4                   228   44           IL   500/1000               1000
# ..                  ...  ...          ...        ...                ...
# 995                   3   38           OH   500/1000               1000
# 996                 285   41           IL    100/300               1000
# 997                 130   34           OH    250/500                500
# 998                 458   62           IL   500/1000               2000
# 999                 456   60           OH    250/500               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip insured_sex  \
# ...

# %% [markdown]
# we have deleted the date column because its the date of the policy when it started

# %% [raw]
# policy_state column

# %%
#lets check the unique values in policy_state column
data['policy_state'].unique()
# Out:
# array(['OH', 'IN', 'IL'], dtype=object)

# %% [markdown]
# There are three unique values in policy_state column so lest just check count values of policy_state column

# %%
#lest count the values of policy_state column
data['policy_state'].value_counts()
# Out:
# OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64

# %%
#lets plot the countplot for policy_state column
sns.countplot(data['policy_state'])
plt.show()

# %%
#need to change or encode the values of policy_state columnby using Label Emcoder
from sklearn.preprocessing import LabelEncoder

# %%
lab1=LabelEncoder()   # instantiate
df1=lab1.fit_transform(data['policy_state'])
data['policy_state']=df1
data
# Out:
#      months_as_customer  age  policy_state policy_csl  policy_deductable  \
# 0                   328   48             2    250/500               1000
# 1                   228   42             1    250/500               2000
# 2                   134   29             2    100/300               2000
# 3                   256   41             0    250/500               2000
# 4                   228   44             0   500/1000               1000
# ..                  ...  ...           ...        ...                ...
# 995                   3   38             2   500/1000               1000
# 996                 285   41             0    100/300               1000
# 997                 130   34             2    250/500                500
# 998                 458   62             0   500/1000               2000
# 999                 456   60             2    250/500               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip insured_sex  \
# ...

# %% [markdown]
# values of policy_state column encoded values are
#
# 1. IL-0
# 2. IN-1
# 3. OH-2

# %% [raw]
# policy_csl Column

# %%
#lets chcek the unique values in policy_csl Column
data['policy_csl'].unique()
# Out:
# array(['250/500', '100/300', '500/1000'], dtype=object)

# %%
#lets count the values of policy_csl column
data['policy_csl'].value_counts()
# Out:
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: policy_csl, dtype: int64

# %%
#lets plot the count plot for policy_csl column
sns.countplot(data['policy_csl'])
plt.show()

# %%
#lest encode this policy_csl column
lab2=LabelEncoder()   #again Instantiating
df2=lab2.fit_transform(data['policy_csl'])
data['policy_csl']=df2
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip insured_sex  \
# ...

# %% [markdown]
# After applying Label encoder in this column
#
# 1. 100/300 - 0
# 2. 250/500 - 1
# 3. 500/1000 -2

# %% [markdown]
# insured_sex Column

# %%
#lets check unique values in insured_sex column
data['insured_sex'].unique()
# Out:
# array(['MALE', 'FEMALE'], dtype=object)

# %% [markdown]
# There are only two unique vlues in insured_sex column male and female

# %%
#lets count the values of insured_sex column
data['insured_sex'].value_counts()
# Out:
# FEMALE    537
# MALE      463
# Name: insured_sex, dtype: int64

# %%
#lets plot the countplot for insured_sex column
sns.countplot(data['insured_sex'])
plt.show()

# %%
#encode the insured_sex column to make in numerical form
lab3=LabelEncoder()     #again Instantiating
df3=lab3.fit_transform(data['insured_sex'])
data['insured_sex']=df3
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [markdown]
# After encode the insured_sex column
#
# 1. Male-1
# 2. Female-0

# %% [raw]
# insured_education_level Column

# %%
#lets check the unique values of insured_education_level column
data['insured_education_level'].unique()
# Out:
# array(['MD', 'PhD', 'Associate', 'Masters', 'High School', 'College',
#        'JD'], dtype=object)

# %%
#lets count the values of insured_education_level column
data['insured_education_level'].value_counts()
# Out:
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: insured_education_level, dtype: int64

# %%
#lets plot the countplot for insured_education_level colum
sns.countplot(data['insured_education_level'])
plt.show()

# %%
#encode the insured_education_level column to normalise the values of this column
lab4=LabelEncoder()  #again instantiating
df4=lab4.fit_transform(data['insured_education_level'])
data['insured_education_level']=df4
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [markdown]
# After encoding the values of  column are
# 1. Associates-0
# 2. College   -1
# 3. High scool-2
# 4. JD        -3
# 5. Masters   -4
# 6. MD        -5
# 7. PhD       -6

# %%
data.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_state                     int32
# policy_csl                       int32
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                      int32
# insured_education_level          int32
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# incident_location               object
# incident_hour_of_the_day         int64
# ...

# %% [raw]
# insured_occupation column

# %%
#lets check the unique values of insured_occupation column
data['insured_occupation'].unique()
# Out:
# array(['craft-repair', 'machine-op-inspct', 'sales', 'armed-forces',
#        'tech-support', 'prof-specialty', 'other-service',
#        'priv-house-serv', 'exec-managerial', 'protective-serv',
#        'transport-moving', 'handlers-cleaners', 'adm-clerical',
#        'farming-fishing'], dtype=object)

# %%
#lets count values of insured_occupation column
data['insured_occupation'].value_counts()
# Out:
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# exec-managerial      76
# sales                76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: insured_occupation, dtype: int64

# %%
#lets plot the countplot for insured_occupation column
sns.countplot(data['insured_occupation'])
plt.xticks(rotation=90)
plt.show()

# %%
#Encode the values of insured_occupation column
lab5=LabelEncoder()
df5=lab5.fit_transform(data['insured_occupation'])
data['insured_occupation']=df5
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [markdown]
# we have encoded the insured_occupation column into int datatype

# %% [raw]
# insured_hobbies Column

# %%
#lets check the unique values of insured_hobbies column
data['insured_hobbies'].unique()
# Out:
# array(['sleeping', 'reading', 'board-games', 'bungie-jumping',
#        'base-jumping', 'golf', 'camping', 'dancing', 'skydiving',
#        'movies', 'hiking', 'yachting', 'paintball', 'chess', 'kayaking',
#        'polo', 'basketball', 'video-games', 'cross-fit', 'exercise'],
#       dtype=object)

# %%
#dropping the insured_hobbies column
data=data.drop(columns=['insured_hobbies'])
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [markdown]
# dropped the insured_hobbies column because i dont think hobbies of insured person would contribute to check the prediction

# %% [raw]
# insured_relationship Column

# %%
#lets check the unique values of insured_relationship column
data['insured_relationship'].unique()
# Out:
# array(['husband', 'other-relative', 'own-child', 'unmarried', 'wife',
#        'not-in-family'], dtype=object)

# %%
#lets check the value count of insured_relationship column
data['insured_relationship'].value_counts()
# Out:
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: insured_relationship, dtype: int64

# %%
#lets plot the countplot for insured_relationship column
sns.countplot(data['insured_relationship'])
plt.xticks(rotation=90)
plt.show()

# %%
#encode the insured_relationship column by using label encoder
lab6=LabelEncoder()
df6=lab6.fit_transform(data['insured_relationship'])
data['insured_relationship']=df6
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [markdown]
# we have successfully encoded the insured_relationship column

# %%
data.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
#        'insured_zip', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_relationship', 'capital-gains',
#        'capital-loss', 'incident_date', 'incident_type', 'collision_type',
#        'incident_severity', 'authorities_contacted', 'incident_state',
#        'incident_city', 'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %% [raw]
# incident_date Column

# %%
#lett just dropped the incident_date column
data=data.drop(columns=['incident_date'])
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [raw]
# incident_type column

# %%
#lets check the unique values of incident_type column
data['incident_type'].unique()
# Out:
# array(['Single Vehicle Collision', 'Vehicle Theft',
#        'Multi-vehicle Collision', 'Parked Car'], dtype=object)

# %%
#lets count the values of incident_type column
data['incident_type'].value_counts()
# Out:
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: incident_type, dtype: int64

# %%
#lets plot the count plot for incident_type column
sns.countplot(data['incident_type'])
plt.xticks(rotation=90)
plt.show()

# %%
#encode the incident_type column
lab7=LabelEncoder()
df7=lab7.fit_transform(data['incident_type'])
data['incident_type']=df7
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [markdown]
# we have succesffully encode the the incident_type  column in int datatype

# %% [raw]
# incident_severity Column

# %%
#lets checl the incident_severity column unique value
data['incident_severity'].unique()
# Out:
# array(['Major Damage', 'Minor Damage', 'Total Loss', 'Trivial Damage'],
#       dtype=object)

# %%
#count the values of incident_severity column
data['incident_severity'].value_counts()
# Out:
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: incident_severity, dtype: int64

# %%
#plot the countplot for incident_severity column
sns.countplot(data['incident_severity'])
plt.show()

# %%
#encode the incident_severity column
lab8=LabelEncoder()
df8=lab8.fit_transform(data['incident_severity'])
data['incident_severity']=df8
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [markdown]
# we have encode the incident_severity column in int datatype

# %% [raw]
# collision_type column

# %%
#lets check the unique values of collision_type column
data['collision_type'].unique()
# Out:
# array(['Side Collision', '?', 'Rear Collision', 'Front Collision'],
#       dtype=object)

# %%
#lets count thr vslue of v column
data['collision_type'].value_counts()
# Out:
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: collision_type, dtype: int64

# %% [markdown]
# There are missing values also in collision_type column

# %%
#lets plot the countplot for collision_type column
sns.countplot(data['collision_type'])
plt.show()

# %%
#replace ? in collision_type column with rear collinson because that are in bigger numbers
data['collision_type']=data['collision_type'].replace('?','Rear Collision')

# %%
#lets check again collision_type column
data['collision_type'].unique()
# Out:
# array(['Side Collision', 'Rear Collision', 'Front Collision'],
#       dtype=object)

# %%
#lets count the values of collision_type column
data['collision_type'].value_counts()
# Out:
# Rear Collision     470
# Side Collision     276
# Front Collision    254
# Name: collision_type, dtype: int64

# %%
#encode the incident_severity column
lab9=LabelEncoder()
df9=lab9.fit_transform(data['collision_type'])
data['collision_type']=df9
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [markdown]
# we have chnaged the collision_type column values in  umbers or changed the datatype

# %% [raw]
# authorities_contacted column

# %%
#lets check the unique values of authorities_contacted column
data['authorities_contacted'].unique()
# Out:
# array(['Police', 'None', 'Fire', 'Other', 'Ambulance'], dtype=object)

# %%
#lets count thr values of authorities_contacted column 
data['authorities_contacted'].value_counts()
# Out:
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# None          91
# Name: authorities_contacted, dtype: int64

# %%
#lets plot the count plot for authorities_contacted column
sns.countplot(data['authorities_contacted'])
plt.show()

# %%
#encode the authorities_contacted column
lab10=LabelEncoder()
df10=lab10.fit_transform(data['authorities_contacted'])
data['authorities_contacted']=df10
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [raw]
# incident_state column

# %%
#lets count the unique values of incident_state column
data['incident_state'].unique()
# Out:
# array(['SC', 'VA', 'NY', 'OH', 'WV', 'NC', 'PA'], dtype=object)

# %%
#lets count the values of incident_state column
data['incident_state'].value_counts()
# Out:
# NY    262
# SC    248
# WV    217
# NC    110
# VA    110
# PA     30
# OH     23
# Name: incident_state, dtype: int64

# %%
#lets plot the countplot for incident_state column
sns.countplot(data['incident_state'])
plt.show()

# %%
#encode the incident_state column
lab11=LabelEncoder()
df11=lab10.fit_transform(data['incident_state'])
data['incident_state']=df11
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [raw]
# incident_city column

# %%
#lets check the uniue values of incident_city column
data['incident_city'].unique()
# Out:
# array(['Columbus', 'Riverwood', 'Arlington', 'Springfield', 'Hillsdale',
#        'Northbend', 'Northbrook'], dtype=object)

# %%
# lets count the values of incident_city column
data['incident_city'].value_counts()
# Out:
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: incident_city, dtype: int64

# %%
#lets plot the countplot for incident_city column
sns.countplot(data['incident_city'])
plt.xticks(rotation=90)
plt.show()

# %%
#encode the incident_city column
lab12=LabelEncoder()
df12=lab10.fit_transform(data['incident_city'])
data['incident_city']=df12
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %%
data.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
#        'insured_zip', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_relationship', 'capital-gains',
#        'capital-loss', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
#lets drop the columns which are not useful to make prediction
data=data.drop(columns=['auto_make','auto_model','auto_year'])
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %%
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [markdown]
# incident_location column

# %%
#lets check the uniuq values of incident_location column
data['incident_location'].unique()
# Out:
# array(['9935 4th Drive', '6608 MLK Hwy', '7121 Francis Lane',
#        '6956 Maple Drive', '3041 3rd Ave', '8973 Washington St',
#        '5846 Weaver Drive', '3525 3rd Hwy', '4872 Rock Ridge',
#        '3066 Francis Ave', '1558 1st Ridge', '5971 5th Hwy',
#        '6655 5th Drive', '6582 Elm Lane', '6851 3rd Drive',
#        '9573 Weaver Ave', '5074 3rd St', '4546 Tree St',
#        '3842 Solo Ridge', '8101 3rd Ridge', '5380 Pine St',
#        '8957 Weaver Drive', '2526 Embaracadero Ave', '5667 4th Drive',
#        '2502 Apache Hwy', '3418 Texas Lane', '2533 Elm St',
#        '3790 Andromedia Hwy', '3220 Rock Drive', '2100 Francis Drive',
#        '4687 5th Drive', '9038 2nd Lane', '6092 5th Ave',
#        '8353 Britain Ridge', '3540 Maple St', '3104 Sky Drive',
#        '4981 Weaver St', '6676 Tree Lane', '3930 Embaracadero St',
#        '3422 Flute St', '4862 Lincoln Hwy', '5719 2nd Lane',
#        '3221 Solo Ridge', '6660 MLK Drive', '1699 Oak Drive',
# ...

# %%
# better to drop incident_location column because there is alot of option which we can cahnged in numerical but not reuires
data=data.drop(columns=['incident_location'])
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [raw]
# incident_hour_of_the_day column

# %%
# lest check the uniuq values in incident_hour_of_the_day column
data['incident_hour_of_the_day'].unique()
# Out:
# array([ 5,  8,  7, 20, 19,  0, 23, 21, 14, 22,  9, 12, 15,  6, 16,  4, 10,
#         1, 17,  3, 11, 13, 18,  2], dtype=int64)

# %% [markdown]
# its already in int datatype we can proceed to another column

# %% [markdown]
# property_damage column

# %%
#lets check the unique values in property_damage column
data['property_damage'].unique()
# Out:
# array(['YES', '?', 'NO'], dtype=object)

# %%
#lets count the values in property_damage column
data['property_damage'].value_counts()
# Out:
# ?      360
# NO     338
# YES    302
# Name: property_damage, dtype: int64

# %%
#lets plot the countplot for property_damage column
sns.countplot(data['property_damage'])
plt.show()

# %% [markdown]
# we will replace the ? data to the no value of the property_damage column

# %%
# lets replace ? value to the no value
data['property_damage']=data['property_damage'].replace('?','NO')

# %%
#again check the unique values of property_damage column
data['property_damage'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
#again plot the countplot fot property_damage values
sns.countplot(data['property_damage'])
plt.show()

# %%
#encode the incident_city column
lab13=LabelEncoder()
df13=lab13.fit_transform(data['property_damage'])
data['property_damage']=df13
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [raw]
# police_report_available column

# %%
#lets check the unique values of police_report_available column
data['police_report_available'].unique()
# Out:
# array(['YES', '?', 'NO'], dtype=object)

# %%
# count the values of police_report_available column
data['police_report_available'].value_counts()
# Out:
# NO     343
# ?      343
# YES    314
# Name: police_report_available, dtype: int64

# %%
#lets plot the countplot for police_report_available column
sns.countplot(data['police_report_available'])
plt.show()

# %%
#lets replace the ? values of police_report_available column to the no values
data['police_report_available']=data['police_report_available'].replace('?','NO')

# %%
#again check the uniuqe values of police_report_available column
data['police_report_available'].unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
#encode the police_report_available column
lab14=LabelEncoder()
df14=lab14.fit_transform(data['police_report_available'])
data['police_report_available']=df14
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [markdown]
# we have succesffuly conert the values of police_report_available column to thr int value

# %% [raw]
# umbrella_limit Column

# %%
#let check is there any nan values in umbrella_limit column
data['umbrella_limit'].isna().sum()
# Out:
# 0

# %%
#lets replace nan values in umbrella_limit column
data['umbrella_limit']=data['umbrella_limit'].fillna(data['umbrella_limit'].mean())

# %%
#again check is there nan values in umbrella_limit column
data['umbrella_limit'].isna().sum()
# Out:
# 0

# %% [markdown]
# fraud_reported column

# %%
# lets check the unique values of fraud_reported column
data['fraud_reported'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
#leta count the values of fraud_reported column
data['fraud_reported'].value_counts()
# Out:
# N    753
# Y    247
# Name: fraud_reported, dtype: int64

# %%
#lets plot the countplot for fraud_reported column
sns.countplot(data['fraud_reported'])
plt.show()

# %%
#encode the fraud_reported column
lab15=LabelEncoder()
df15=lab15.fit_transform(data['fraud_reported'])
data['fraud_reported']=df15
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %%
#lets check the unique value again of fraud_reported column
data['fraud_reported'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# we have sucessfully converted all the object type value ito int datatype so that we can checj the normally distributed

# %%
#lets checj tha datatypes of all the column
data.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_state                     int32
# policy_csl                       int32
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                      int32
# insured_education_level          int32
# insured_occupation               int32
# insured_relationship             int32
# capital-gains                    int64
# capital-loss                     int64
# incident_type                    int32
# collision_type                   int32
# incident_severity                int32
# authorities_contacted            int32
# incident_state                   int32
# incident_city                    int32
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                  int32
# bodily_injuries                  int64
# ...

# %% [markdown]
# all the datatypes of all the columns are now int or float so we can proceed further

# %%
#check the null values in the whole dataset
data.isna().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# total_claim_amount             0
# injury_claim                   0
# ...

# %%
#lets plot a graph to check null values
sns.heatmap(data.isna())
plt.show()

# %% [markdown]
# There are now null values present in the columns of the dataset we can proceed further

# %%
#new shape of data
data.shape
# Out:
# (1000, 31)

# %%
#lets check the normalization
plt.figure(figsize=(20,20))
plotnumber=1
for column in data:
    if plotnumber<=31:
        ax=plt.subplot(8,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %% [markdown]
# max of the columns are normally distributed and the values which have 0,1,2,3,4 etc are can't br normally distributed because of the values they contained

# %%
#checking correlation
plt.figure(figsize=(20,20))
data_corr=data.corr()
sns.heatmap(data_corr,annot=True,annot_kws={'size':10})
plt.show()

# %% [markdown]
# total_claim_amount and vehicle claim are 98 % correlated

# %%
plt.scatter(x=data['total_claim_amount'],y=data['vehicle_claim'])
plt.xlabel('Total claim amount')
plt.ylabel('vehicle claim')
plt.show()

# %% [markdown]
# these two are highly correaled so we drop onw and that is vehicle claim

# %%
#dropping vehicle_claim 
data=data.drop(columns=['vehicle_claim'])
data
# Out:
#      months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                   328   48             2           1               1000
# 1                   228   42             1           1               2000
# 2                   134   29             2           0               2000
# 3                   256   41             0           1               2000
# 4                   228   44             0           2               1000
# ..                  ...  ...           ...         ...                ...
# 995                   3   38             2           2               1000
# 996                 285   41             0           0               1000
# 997                 130   34             2           1                500
# 998                 458   62             0           2               2000
# 999                 456   60             2           1               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  insured_sex  \
# ...

# %% [markdown]
# we have vehicle claim because thats are corelated to total calim

# %% [markdown]
# where as age and months as customer are also highly corelated that is 92%

# %%
#again check the corelation between age and months as customer
plt.scatter(x=data['age'],y=data['months_as_customer'])
plt.xlabel('Age')
plt.ylabel('Months as Customer')
plt.show()

# %% [markdown]
# these are also highly corelated but we cannot delete any of the column or we can check further on VIF

# %%
#plotting boxplot to check outliers
data.plot(kind='box',subplots = True,layout=(8,4),figsize = (25,25))
plt.show()

# %% [markdown]
# in 2 or 3 columns have skewness or outliers we can rectify it with functions

# %%
#now check the skewness
data.skew()
# Out:
# months_as_customer             0.362177
# age                            0.478988
# policy_state                  -0.026177
# policy_csl                     0.088928
# policy_deductable              0.477887
# policy_annual_premium          0.004402
# umbrella_limit                 1.806712
# insured_zip                    0.816554
# insured_sex                    0.148630
# insured_education_level       -0.000148
# insured_occupation            -0.058881
# insured_relationship           0.077488
# capital-gains                  0.478850
# capital-loss                  -0.391472
# incident_type                  0.101507
# collision_type                -0.033682
# incident_severity              0.279016
# authorities_contacted         -0.121744
# incident_state                -0.148865
# incident_city                  0.049531
# incident_hour_of_the_day      -0.035584
# number_of_vehicles_involved    0.502664
# property_damage                0.863806
# ...

# %%
#making the skew less than or equal to 0.55 for better prediction and plotting Normal distribution
#skew=('umbrella_limit')
#for col in skew:
    #if data.skew().loc[col]>0.55:
        #data[col]=np.log1p(data[col])

# %%
#again check the skewness
data.skew()
# Out:
# months_as_customer             0.362177
# age                            0.478988
# policy_state                  -0.026177
# policy_csl                     0.088928
# policy_deductable              0.477887
# policy_annual_premium          0.004402
# umbrella_limit                 1.806712
# insured_zip                    0.816554
# insured_sex                    0.148630
# insured_education_level       -0.000148
# insured_occupation            -0.058881
# insured_relationship           0.077488
# capital-gains                  0.478850
# capital-loss                  -0.391472
# incident_type                  0.101507
# collision_type                -0.033682
# incident_severity              0.279016
# authorities_contacted         -0.121744
# incident_state                -0.148865
# incident_city                  0.049531
# incident_hour_of_the_day      -0.035584
# number_of_vehicles_involved    0.502664
# property_damage                0.863806
# ...

# %% [markdown]
# ###### Splitting the data

# %%
x=data.drop(columns=['fraud_reported'])
y=data['fraud_reported']

# %%
#check shape of x and y 
print('Shape of x is :',x.shape,'\n\n') 
print('Shape of y is :',y.shape,'\n\n')
# Out:
# Shape of x is : (1000, 29)
#
#
# Shape of y is : (1000,)

# %%
#check relationship between x and y 
plt.figure(figsize=(20,20))
plotnumber=1
for column in x:
    if plotnumber<=16:
        ax=plt.subplot(8,4,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize=10)
        plt.ylabel('fraud_reported')
    plotnumber+=1
plt.show()

# %%
#importing standard scler to scale the x 
from sklearn.preprocessing import StandardScaler

# %%
s1=StandardScaler()  #instantiate
scaled1=s1.fit_transform(x)
scaled1.shape[1]
# Out:
# 29

# %%
#import train_test_split
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(scaled1,y,test_size=0.40,random_state=123)

# %% [markdown]
# ###### 1st Model Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve

# %%
lr=LogisticRegression()  #instantiate
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#Trainig Accuracy of Logistic Regression Model
lr.score(x_train,y_train)
# Out:
# 0.8116666666666666

# %%
y_pred_lr=lr.predict(x_test)

# %%
#testing accuracy of Logistic Regression Model
accuracy_score(y_test,y_pred_lr)
# Out:
# 0.7625

# %% [markdown]
# Training score of Logictis Regression Model- 81%
#
# Testing score of Logictis Regression Model- 76%

# %%
#confusion matric of logistic Regression Model
confusion_matrix(y_test,y_pred_lr)
# Out:
# array([[268,  36],
#        [ 59,  37]], dtype=int64)

# %%
#classification report
print(classification_report(y_test,y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       304
#            1       0.51      0.39      0.44        96
#
#     accuracy                           0.76       400
#    macro avg       0.66      0.63      0.64       400
# weighted avg       0.74      0.76      0.75       400

# %%
#plt_roc_curve for Logistic Regression Model
fpr,tpr,thresholds=roc_curve(y_test,y_pred_lr)

# %%
print('False Positive Rates are :',fpr)
print('True Positive Rates are :',tpr)
print('Thresholds are :',thresholds)
# Out:
# False Positive Rates are : [0.         0.11842105 1.        ]
# True Positive Rates are : [0.         0.38541667 1.        ]
# Thresholds are : [2 1 0]

# %%
plt.plot(fpr,tpr,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='darkblue')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Logistic Regression model')
plt.legend()
plt.show()

# %%
#conclusion of Logistic Regression Model
plt.scatter(y_test,y_pred_lr)
plt.xlabel('Actual')
plt.ylabel('Prediction')
plt.show()

# %% [markdown]
# ###### 2nd Model KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()  #instantiate
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
#Training accuracy of KNN model
knn.score(x_train,y_train)
# Out:
# 0.8066666666666666

# %%
y_pred_knn=knn.predict(x_test)

# %%
#Testing accuracy of KNN Model
accuracy_score(y_test,y_pred_knn)
# Out:
# 0.7225

# %% [markdown]
# Training Accuracy of KNN Model -80%
#
# Testing Accuracy of KNN Model -72%

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %% [markdown]
# ###### Hyperparameter Tuning for KNN Model

# %%
#select best features
best_features=SelectKBest(score_func=f_classif,k=13)
fit=best_features.fit(x,y)
data_scores=pd.DataFrame(fit.scores_)
data_columns=pd.DataFrame(x.columns)
#concatenate
feature_scores=pd.concat([data_columns,data_scores], axis=1)
feature_scores.columns=['Feature_Name','score']
print(feature_scores.nlargest(13,'score'))
# Out:
#                    Feature_Name       score
# 16            incident_severity  196.960603
# 26           total_claim_amount   27.463776
# 28               property_claim   19.327729
# 27                 injury_claim    8.328776
# 6                umbrella_limit    3.441452
# 21  number_of_vehicles_involved    2.689100
# 18               incident_state    2.644427
# 14                incident_type    2.539153
# 24                    witnesses    2.451026
# 17        authorities_contacted    2.098018
# 19                incident_city    1.631761
# 3                    policy_csl    1.382236
# 23              bodily_injuries    1.146656

# %%
#Model Building
new_x=data[['incident_severity','total_claim_amount','property_claim','injury_claim','umbrella_limit','number_of_vehicles_involved','incident_state','incident_type','witnesses','authorities_contacted','incident_city','policy_csl','bodily_injuries']]
new_x
# Out:
#      incident_severity  total_claim_amount  property_claim  injury_claim  \
# 0                    0               71610           13020          6510
# 1                    1                5070             780           780
# 2                    1               34650            3850          7700
# 3                    0               63400            6340          6340
# 4                    1                6500             650          1300
# ..                 ...                 ...             ...           ...
# 995                  1               87200            8720         17440
# 996                  0              108480           18080         18080
# 997                  1               67500            7500          7500
# 998                  0               46980            5220          5220
# 999                  1                5060             920           460
#
#      umbrella_limit  number_of_vehicles_involved  incident_state  \
# ...

# %%
#scalling the new x
scaler=StandardScaler()
scaled_new_x=scaler.fit_transform(new_x)
scaled_new_x
# Out:
# array([[-1.26061352,  0.71425742,  1.16550497, ..., -0.96219565,
#          0.06093665,  0.00975947],
#        [-0.19590615, -1.80731185, -1.37269599, ...,  0.99547607,
#          0.06093665, -1.21017372],
#        [-0.19590615, -0.68636176, -0.73607206, ..., -0.96219565,
#         -1.18266843,  1.22969265],
#        ...,
#        [-0.19590615,  0.55850675,  0.0208261 , ..., -1.45161357,
#          0.06093665,  1.22969265],
#        [-1.26061352, -0.21910974, -0.45197603, ..., -1.45161357,
#          1.30454172, -1.21017372],
#        [-0.19590615, -1.80769081, -1.34366428, ..., -0.96219565,
#          0.06093665, -1.21017372]])

# %%
#again instantiating for hyperparameter tuning
knn1=KNeighborsClassifier()
knn1.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn1=knn1.predict(x_test)

# %%
#accuracy of training data
knn1.score(x_train,y_train)
# Out:
# 0.8066666666666666

# %%
#Testing Score of KNN Model after Hyperparameter 
accuracy_score(y_test,y_pred_knn1)
# Out:
# 0.7225

# %% [markdown]
# Training Accuracy of KNN Model after hyperparameter -80%
#
# Testing Accuracy of KNN Model after aparameter -72%
#
# the accuracy remains the same with or without parameter

# %%
#confusion matric of KNN Model
confusion_matrix(y_test,y_pred_knn)
# Out:
# array([[279,  25],
#        [ 86,  10]], dtype=int64)

# %%
#classification report
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.92      0.83       304
#            1       0.29      0.10      0.15        96
#
#     accuracy                           0.72       400
#    macro avg       0.53      0.51      0.49       400
# weighted avg       0.65      0.72      0.67       400

# %%
#plt_roc_curve for Logistic Regression Model
fpr1,tpr1,thresholds1=roc_curve(y_test,y_pred_knn)

# %%
print('False Positive Rates are :',fpr1)
print('True Positive Rates are :',tpr1)
print('Thresholds are :',thresholds1)
# Out:
# False Positive Rates are : [0.         0.08223684 1.        ]
# True Positive Rates are : [0.         0.10416667 1.        ]
# Thresholds are : [2 1 0]

# %%
plt.plot(fpr1,tpr1,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='darkblue')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for knn model')
plt.legend()
plt.show()

# %% [markdown]
# Not that good model for this problem as its not cover the big data space

# %%
#conclusions of KNN Model
plt.scatter(y_test,y_pred_knn)
plt.xlabel('Actual')
plt.ylabel('Prediction')
plt.title('KNN Model')
plt.show()

# %% [markdown]
# ###### 3rd Model Decision Tree Classifier Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()  #instantiate
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Training score of Decision tree Model
dt.score(x_train,y_train)
# Out:
# 1.0

# %%
y_pred_dt=dt.predict(x_test)

# %%
#Accuracy of testing data
accuracy_score(y_test,y_pred_dt)
# Out:
# 0.705

# %% [markdown]
# Training score of Decision Tree Model is 100%
#
# Testing Score of Decision Tree Model is 70%

# %% [markdown]
# ###### Hyperparameter tuning for Decision Tree Model

# %%
grid_params1={'max_depth':[1,2,3,4,5,6,7,8],
              'min_samples_leaf':[1,2,3,4,5,6,7,8],
               'max_features':['auto','log2','sqrt',None],
               'max_leaf_nodes':[1,2,3,4,5,6,7,8]}
print(grid_params1)
# Out:
# {'max_depth': [1, 2, 3, 4, 5, 6, 7, 8], 'min_samples_leaf': [1, 2, 3, 4, 5, 6, 7, 8], 'max_features': ['auto', 'log2', 'sqrt', None], 'max_leaf_nodes': [1, 2, 3, 4, 5, 6, 7, 8]}

# %%
from sklearn.model_selection import GridSearchCV
grid_dt=GridSearchCV(dt,param_grid=grid_params1,cv=3,verbose=3)

# %%
grid_dt.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 2048 candidates, totalling 6144 fits
# [CV 1/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=1; total time=   0.0s
# [CV 2/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=1; total time=   0.0s
# [CV 3/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=1; total time=   0.0s
# [CV 1/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=2; total time=   0.0s
# [CV 2/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=2; total time=   0.0s
# [CV 3/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=2; total time=   0.0s
# [CV 1/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=3; total time=   0.0s
# [CV 2/3] END max_depth=1, max_features=auto, max_leaf_nodes=1, min_samples_leaf=3; total time=   0.0s
# ...

# %%
# best hyperparameters 
grid_dt.best_params_
# Out:
# {'max_depth': 1,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': 8,
#  'min_samples_leaf': 8}

# %%
#best aparameter model score
grid_dt.best_score_
# Out:
# 0.8016666666666667

# %%
#traininf decision tree with hyperparameter feature
dt_hyp=DecisionTreeClassifier(max_depth = 1,max_features= 'sqrt',max_leaf_nodes = 8,min_samples_leaf= 8)

# %%
#noe fitting decsiontree hyperparameter
dt_hyp.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=1, max_features='sqrt', max_leaf_nodes=8,
#                        min_samples_leaf=8)

# %%
y_pred_dt1=dt_hyp.predict(x_test)

# %%
#trainig accuracy of hyperparameter of Dt model
dt_hyp.score(x_train,y_train)
# Out:
# 0.7483333333333333

# %%
#Testing score of Decision Tree Model after Hyperparameter
accuracy_score(y_test,y_pred_dt1)
# Out:
# 0.76

# %% [markdown]
# Training score of Decision Tree Model Afetr Hyperparameter  is 70%
#
# Testing Score of Decision Tree Model After Hyperparameter is 76%

# %%
#confusion matric of KNN Model
confusion_matrix(y_test,y_pred_dt1)
# Out:
# array([[304,   0],
#        [ 96,   0]], dtype=int64)

# %%
#Classification report of Deciison Tree Model
print(classification_report(y_test,y_pred_dt1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86       304
#            1       0.00      0.00      0.00        96
#
#     accuracy                           0.76       400
#    macro avg       0.38      0.50      0.43       400
# weighted avg       0.58      0.76      0.66       400

# %%
#plot roc curve for Decision Tree Model
fpr2,tpr2,thresholds2=roc_curve(y_test,y_pred_dt1)

# %%
print('False Positive Rates are :',fpr2)
print('True Positive Rates are :',tpr2)
print('Thresholds are :',thresholds2)
# Out:
# False Positive Rates are : [0. 1.]
# True Positive Rates are : [0. 1.]
# Thresholds are : [1 0]

# %%
plt.plot(fpr2,tpr2,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='darkblue')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Tree model')
plt.legend()
plt.show()

# %%
#conclusion for Decision Tree Model
plt.scatter(y_test,y_pred_dt)
plt.xlabel('Actual')
plt.ylabel('Prediction')
plt.title('Decision tree Model')
plt.show()

# %% [markdown]
# ###### 4th Model Random Forest Classifier Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()  #instantiate
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#Training score of Random Forest Classifier Model
rf.score(x_train,y_train)
# Out:
# 1.0

# %%
y_pred_rf=rf.predict(x_test)

# %%
#Testing score of Random Forest Model
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.77

# %% [markdown]
# Training Score of Random Forest Classifier is -100%
#
# Testing score of Random Forest Classifier is -77 %

# %% [markdown]
# ###### Hyperparameter Tuning for Random Forest Model

# %%
params={'n_estimators':[13,15],
       'criterion':['entropy'],
       'max_depth':[10,15],
       'min_samples_split':[10,11],
       'min_samples_leaf':[5,6]
       }

grd=GridSearchCV(rf,param_grid=params)
grd.fit(x_train,y_train)
print('best_params=>',grd.best_params_)

rf=grd.best_estimator_

rf.fit(x_train,y_train)
y_pred_rf1=rf.predict(x_test)

rf_conf_mat=confusion_matrix(y_test,y_pred_rf1)

print('\ncon_mat','\n',rf_conf_mat)
print('\n Accuracy rf normal',accuracy_score(y_test,y_pred_rf1))
# Out:
# best_params=> {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 15}
#
# con_mat
#  [[279  25]
#  [ 62  34]]
#
#  Accuracy rf normal 0.7825

# %%
accuracy_score(y_test,y_pred_rf1)
# Out:
# 0.7825

# %% [markdown]
# after tuning the Random Forest Model the accuracy decreases from 1% so we stick to without tuning model

# %%
#plot roc curve for Decision Tree Model
fpr3,tpr3,thresholds3=roc_curve(y_test,y_pred_rf1)

# %%
print('False Positive Rates are :',fpr3)
print('True Positive Rates are :',tpr3)
print('Thresholds are :',thresholds3)
# Out:
# False Positive Rates are : [0.         0.08223684 1.        ]
# True Positive Rates are : [0.         0.35416667 1.        ]
# Thresholds are : [2 1 0]

# %%
plt.plot(fpr3,tpr3,color='orange',label='ROC')
plt.plot([0,1],[0,1],color='darkblue')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Random Forest model')
plt.legend()
plt.show()

# %%
#conclusions of Random Forest Model
plt.scatter(y_test,y_pred_rf)
plt.xlabel('Actual')
plt.ylabel('Prediction')
plt.title('Random Forest Model')
plt.show()

# %% [markdown]
# ###### Plot_roc_curve for fitted model

# %%
#training with all classifier
lr.fit(x_train,y_train)
dt.fit(x_train,y_train)
rf.fit(x_train,y_train)
knn.fit(x_train,y_train)

print('All Models are trained')
# Out:
# All Models are trained

# %%
#all models scores are captured
lr.score(x_test,y_test)
dt.score(x_test,y_test)
rf.score(x_test,y_test)
knn.score(x_test,y_test)

print('All Models test score captured')
# Out:
# All Models test score captured

# %%
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.metrics import plot_roc_curve
disp=plot_roc_curve(dt,x_test,y_test)
plot_roc_curve(lr,x_test,y_test,ax=disp.ax_)
plot_roc_curve(knn,x_test,y_test,ax=disp.ax_)
plot_roc_curve(rf,x_test,y_test,ax=disp.ax_)
plt.legend(prop={'size':11},loc='lower right')
plt.show()

# %% [markdown]
# Accuracy of each model is
#
# 1. Logistic Regression-76%
# 2. KNeighborsclassifier-55%
# 3. DecisionTreeClassifier-76%
# 4.RandomForestClassifier-77%
#
# so we choose Random forest classifier to save our model

# %%
import pickle

# %%
filename='Insurance_claim.pkl'

# %%
pickle.dump=(rf,open('insurance_claim.pkl','wb'))
